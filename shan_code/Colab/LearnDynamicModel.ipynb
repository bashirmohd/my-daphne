# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-589edbe5-fcd5-48f9-9105-076924915de0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-589edbe5-fcd5-48f9-9105-076924915de0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving topo.json to topo.json
# Saving topo2.json to topo2.json
# Saving topo3.json to topo3.json

# %%
import numpy as np
import os
import sys
import json
import random

import torch
import torch.nn as nn
from torch.autograd import Variable
import matplotlib.pyplot as plt

# %%
def read_json_file(filename):
    with open(filename) as f:
        js_data = json.load(f)

        nodes = js_data['data']['mapTopology']['nodes']
        edges = js_data['data']['mapTopology']['edges']

        return(nodes, edges)


class network_env:
    def __init__(self, topo_file):

        self.nodes, self.edges = read_json_file(topo_file)
        self.edgesList = []
        self.Edgelist_gen()
        self.avail_util_paths = np.zeros([len(self.edgesList)])
        self.Path_utilization_gen()
        self.active_flows = []

    def step1(self, State, action, flow):


        flag = False
        for af in self.active_flows:

            af.counter -= 1
        if self.avail_util_paths[action] > flow.size:
            self.avail_util_paths[action] -= flow.size
            State.rec_flow_size.pop(0)
            State.rec_flow_dur.pop(0)
            State.rec_flow_action.pop(0)
            State.rec_flow_size.append(flow.size)
            State.rec_flow_dur.append(flow.dur)
            State.rec_flow_action.append(action)
            flow.allocated_to = action
            # print("flowsize", flow.size)
            # print("action", action)
            # print(flow.size)
            # print(flow.allocated_to)
            flow.counter += self.edgesList[action].lat
            # print(self.edgesList[action].lat)
            self.active_flows.append(flow)
            flag = True
        
        for af in self.active_flows:
        # print("allocatedto", self.active_flows[index].allocated_to)
        # print("activeflowsize", self.active_flows[index].size)
        
            if af.counter <= 0:
            
                self.active_flows.remove(af)
                # print('sss')
                # print(self.avail_util_paths[af.allocated_to])
                self.avail_util_paths[af.allocated_to] += af.size
                # print("allocated_to", af.allocated_to)
                # print(self.avail_util_paths[af.allocated_to])
                

        return flag, State
    def step2(self, State, flow):
        State.curr_flow = flow

        return State

    def reward(self):

        min_util = 1
        for index in range(len(self.edgesList)):
            # print('edgebw', self.edgesList[index].bw )
            # print("pathava", self.avail_util_paths[index])
            temp = (self.edgesList[index].bw - self.avail_util_paths[index]) / self.edgesList[index].bw
            if temp < min_util:
                min_util = temp
            return min_util
           
    def reset(self, k, curr_flow):
        rec_flow_size = []
        rec_flow_dur = []
        rec_flow_action = []

        for _ in range(k):
            EorM = random.randint(0, 9)
            # if between 2-9 mouse else elephant
            if (EorM > 1):
                rec_flow_size.append(random.randint(1, 2))
                rec_flow_dur.append(random.randint(1, 3))
                rec_flow_action.append(random.randint(0, len(self.edgesList)-1))
            else:
                rec_flow_size.append(random.randint(3, 5))
                rec_flow_dur.append(random.randint(10, 15))
                rec_flow_action.append(random.randint(0, len(self.edgesList) - 1))
                # print(rec_flow_size)
                # print(rec_flow_dur)
                # print(rec_flow_action)
        curr_state = GameState(rec_flow_size, rec_flow_dur, rec_flow_action, curr_flow)

        return curr_state
    def Edgelist_gen(self):
        i = 0
        for e in self.edges:
            edge_detail = Edge(i, i, e['BW'], e['Lat'], 'SRC', 'DST')
            i = i + 1
            self.edgesList.append(edge_detail)

   def Path_utilization_gen(self):

        for index in range(len(self.edgesList)):
            edge = self.edgesList[index]
            self.avail_util_paths[index] = edge.bw

def Generate_flow(Total_Flows, perc_ele): ##### Now the elephant rate is 20%
    all_flows = []
    # generate elephant or mice flow 100 flows
    for f in range(Total_Flows):
        EorM = random.uniform(0, 9)
        # if between 2-9 mouse else elephant
        if (EorM > 10 * perc_ele - 1):
            flowname = "mouse"
            flowsize = random.randint(1, 2)
            flowdur = random.randint(1, 3)
        else:
            flowname = "elephant"
            flowsize = random.randint(3, 5)
            flowdur = random.randint(10, 15)

            # print(flowname, flowsize, flowdur)
            # add active flows to queue
        flow_created = FlowTraffic(f, flowname, flowsize, flowdur)
        all_flows.append(flow_created)

    return all_flows


class GameState:
    def __init__(self, rec_flow_size, rec_flow_dur, rec_flow_action, curr_flow):
        self.rec_flow_size = rec_flow_size
        self.rec_flow_dur = rec_flow_dur
        self.rec_flow_action = rec_flow_action
        self.curr_flow = curr_flow

class Site(object):
    def __init__(self, num, siteID, name):



        self.num = num
        self.siteID = siteID
        self.name = name
            # print("New Site Node created with name:")
            # print(name)


class Edge(object):


    def __init__(self, num, edgeID, bw, lat, node1, node2):
        self.num = num
        self.edgeID = edgeID
        self.bw = bw
        self.lat = lat
        self.node1 = node1
        self.node2 = node2
        # print("New Edge created with id: %d" % edgeId)


class FlowTraffic(object):


    def __init__(self, num, name, size, dur):
        self.num = num
        self.name = name
        self.size = size
        self.dur = dur
        self.counter = dur
        self.allocated_to = None

# %%
class Model(nn.Module):
    def __init__(self, input_shape, output_shape, hid_shape, hid_num, minibatch_size, activation='tanh'):
        super().__init__()
        self.input_shape = input_shape
        self.output_shape = output_shape
        self.hid_shape = hid_shape
        self.hid_num = hid_num
        self.minibatch_size = minibatch_size
        if activation == 'tanh':
            self.activation = [nn.Tanh, torch.tanh]
        elif activation == 'relu':
            self.activation = [nn.ReLU, torch.relu]
        else:
            raise Exception('unsupported activation type')

        layers = [nn.Linear(self.input_shape, self.hid_shape), self.activation[0]()]
        for _ in range(self.hid_num):
            layers.extend([nn.Linear(self.hid_shape, self.hid_shape), self.activation[0]()])
        layers.append(nn.Linear(self.hid_shape, self.output_shape))
        self.model = nn.Sequential(*layers)

    def forward(self, x):

        return self.model(x)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
topology_file = ["topo.json", "topo2.json", "topo3.json"]


Episodes_Number = 50
K = 100
Max_Total_Flows = 5000
Min_Total_Flows = 3000
Input_shape = K * 3 + 3
Output_shape = 1
Hid_shape = 300
Hid_num = 6
Learning_rate = 1e-5
Minibatch_size = 50
Epochs = 20
Replay_size = 50000
Percent_of_elephant = [0.2, 0.25, 0.3]

def get_minibatch(samples, batch_size):
    State = []
    Reward = []
    for d in samples:
        state_list = []
        reward_list = []
        state = d[0]
        action = d[1]
        reward = d[2]
        state_list.extend(state.rec_flow_size)
        state_list.extend(state.rec_flow_dur)
        state_list.extend(state.rec_flow_action)
        state_list.append(state.curr_flow.size)
        state_list.append(state.curr_flow.dur)
        state_list.append(action)
        State.append(state_list)
        # print(reward)
        Reward.append([reward])
    # print(minibatch_state)
    State = torch.tensor(State).float()
    Reward = torch.tensor(Reward).float()
    train_data = torch.utils.data.TensorDataset(State, Reward)
    train_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size, shuffle=True)

    return train_loader




def training():

    criterion = nn.MSELoss()
    model = Model(Input_shape, Output_shape, Hid_shape, Hid_num, Minibatch_size)
    model.to(device)
    # task = random.randint(0, 2)
    replay_memory = []
    Loss = []
    task = 0
    env = network_env(topology_file[task])

    for episode in range(Episodes_Number):
        total_flows_num = random.randint(Min_Total_Flows, Max_Total_Flows)
        if episode == 20:
            task = 1
            env = network_env(topology_file[task])
            replay_memory = []
        if episode == 40:
            task = 2
            env = network_env(topology_file[task])
            replay_memory = []

        All_flows = Generate_flow(total_flows_num, Percent_of_elephant[0])
        curr_flow = All_flows[0]
        Curr_state = env.reset(K, curr_flow)
        iter = 0   
        while len(All_flows) > 1:
            action = random.randint(0, len(env.edgesList) -1)
            flag, Next_state = env.step1(Curr_state, action, curr_flow)
            if flag:
                All_flows.remove(curr_flow)
                curr_flow = All_flows[0]
                Next_state = env.step2(Next_state, curr_flow)
            # print('flag', flag)
            # print("Path availibity", env.avail_util_paths)
            Reward = env.reward()
            # print('reward', Reward)
            # save transition to replay memory
            replay_memory.append((Curr_state, action, Reward, Next_state))
            # if replay memory is full, remove the oldest transition
            if len(replay_memory) > Replay_size:
                replay_memory.pop(0)
        optimizer = torch.optim.SGD(model.parameters(), lr = Learning_rate)
        trainloader = get_minibatch(replay_memory, model.minibatch_size)
        # sample random minibatch
        running_loss = 0.0
        for epoch in range(Epochs):  # loop over the dataset multiple times
          
            for i, data in enumerate(trainloader, 0):
                # get the inputs; data is a list of [inputs, labels]
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()
                # if i % 2 == 0:    # print every 2000 mini-batches
            print("Episode", episode)
            print("Epoch", epoch)
            print("Loss", running_loss / i)
        Loss.append(running_loss / (Epochs * i))
        

# print(replay_memory)
    plt.figure(0)
    plt.plot(Loss)
    plt.ylabel('Trainning loss')
    plt.xlabel("Episodes")
    plt.grid(True)
    plt.title("Batch size = {}, Learning Rate = {}".format(Minibatch_size,Learning_rate))
    plt.show()

# Run agent functions

def test():
   print("test")



def main():
    training()
    test()

# %%
main()
# Out:
# Episode 0
# Epoch 0
# Loss 0.15558813978927305
# Episode 0
# Epoch 1
# Loss 0.3096363845497671
# Episode 0
# Epoch 2
# Loss 0.4623088637987773
# Episode 0
# Epoch 3
# Loss 0.6135962022976442
# Episode 0
# Epoch 4
# Loss 0.7633792039270353
# Episode 0
# Epoch 5
# Loss 0.9118626230593884
# Episode 0
# Epoch 6
# Loss 1.059042934968014
# Episode 0
# Epoch 7
# Loss 1.2049226635182746
# Episode 0
# Epoch 8
# Loss 1.3491758429492362
# Episode 0
# Epoch 9
# Loss 1.4923133942665476
# Episode 0
# Epoch 10
# Loss 1.6341304377172932
# Episode 0
# Epoch 11
# Episode 3
# Epoch 4
# Loss 0.3763991266807639
# Episode 3
# Epoch 5
# Loss 0.44902374630205727
# Episode 3
# Epoch 6
# Loss 0.5211201828806415
# Episode 3
# Epoch 7
# Loss 0.5924015587931009
# Episode 3
# Epoch 8
# Loss 0.6629930861147219
# Episode 3
# Epoch 9
# Loss 0.73301339001934
# Episode 3
# Epoch 10
# Loss 0.8025012647488008
# Episode 3
# Epoch 11
# Loss 0.8715139494963775
# Episode 3
# Epoch 12
# Loss 0.9398237118938644
# Episode 3
# Epoch 13
# Loss 1.0077071011899725
# Episode 3
# Epoch 14
# Loss 1.0754099863483326
# Episode 3
# Epoch 15
# Loss 1.1421845665152528
# Episode 3
# Epoch 16
# Loss 1.20858963297582
# Episode 3
# Epoch 17
# Loss 1.2744639199423162
# Episode 3
# Epoch 18
# Loss 1.3398925921640752
# Episode 3
# Epoch 19
# Loss 1.4050701352724757
# Episode 4
# Epoch 0
# Loss 0.06373389728001452
# Episode 4
# Epoch 1
# Loss 0.127080956964554
# Episode 4
# Epoch 2
# Loss 0.19005429533925572
# Episode 4
# Epoch 3
# Loss 0.2526749736446488
# Episode 4
# Epoch 4
# Loss 0.3149796195045513
# Episode 4
# Epoch 5
# Loss 0.37695773798207355
# Episode 4
# Epoch 6
# Loss 0.4386449176069748
# Episode 4
# Epoch 7
# Loss 0.5000669622012148
# Episode 4
# Epoch 8
# Loss 0.5612197779202168
# Episode 4
# Epoch 9
# Loss 0.6221340752007174
# Episode 4
# Epoch 10
# Loss 0.6828086726683458
# Episode 4
# Epoch 11
# Loss 0.7432533783846468
# Episode 4
# Epoch 12
# Loss 0.8035002262955199
# Episode 4
# Epoch 13
# Loss 0.8635547351067154
# Episode 4
# Epoch 14
# Loss 0.9234323009649026
# Episode 4
# Epoch 15
# Loss 0.9831130768039397
# Episode 4
# Epoch 16
# Loss 1.0426466619828716
# Episode 4
# Epoch 17
# Loss 1.1020171411052746
# Episode 4
# Epoch 18
# Loss 1.161241223952467
# Episode 4
# Epoch 19
# Loss 1.2203401324555412
# Episode 5
# Epoch 0
# Loss 0.06122539073515397
# Episode 5
# Epoch 1
# Loss 0.1222264098863189
# Episode 5
# Epoch 2
# Loss 0.18304589423709192
# Episode 5
# Epoch 3
# Loss 0.24371128560115513
# Episode 5
# Epoch 4
# Loss 0.30420332620135293
# Episode 5
# Epoch 5
# Loss 0.36451745642564043
# Episode 5
# Epoch 6
# Loss 0.42472735846486803
# Episode 5
# Epoch 7
# Loss 0.4847937043147305
# Episode 5
# Epoch 8
# Loss 0.544770914205135
# Episode 5
# Epoch 9
# Loss 0.6045896777632431
# Episode 5
# Epoch 10
# Loss 0.664285767569135
# Episode 5
# Epoch 11
# Loss 0.7238809572711874
# Episode 5
# Epoch 12
# Loss 0.7834059518761933
# Episode 5
# Epoch 13
# Loss 0.8428473883523391
# Episode 5
# Epoch 14
# Loss 0.9021919967570844
# Episode 5
# Epoch 15
# Loss 0.9614552878738882
# Episode 5
# Epoch 16
# Loss 1.0206710082944483
# Episode 5
# Epoch 17
# Loss 1.0798083380867656
# Episode 5
# Epoch 18
# Loss 1.138920198685418
# Episode 5
# Epoch 19
# Loss 1.1979281347495718
# Episode 6
# Epoch 0
# Loss 0.05929449768001704
# Episode 6
# Epoch 1
# Loss 0.1185485340201443
# Episode 6
# Epoch 2
# Loss 0.17773563410523102
# Episode 6
# Epoch 3
# Loss 0.23684879294657885
# Episode 6
# Epoch 4
# Loss 0.29590893159681736
# Episode 6
# Epoch 5
# Loss 0.3549217250179744
# Episode 6
# Epoch 6
# Loss 0.41389244205416426
# Episode 6
# Epoch 7
# Loss 0.47280280811307757
# Episode 6
# Epoch 8
# Loss 0.5316823806405362
# Episode 6
# Epoch 9
# Loss 0.5905237683940581
# Episode 6
# Epoch 10
# Loss 0.6493488227776987
# Episode 6
# Epoch 11
# Loss 0.70813939869894
# Episode 6
# Epoch 12
# Loss 0.7668890746702489
# Episode 6
# Epoch 13
# Loss 0.8256036547521178
# Episode 6
# Epoch 14
# Loss 0.8842970397059904
# Episode 6
# Epoch 15
# Loss 0.9429554324382671
# Episode 6
# Epoch 16
# Loss 1.0016040057066435
# Episode 6
# Epoch 17
# Loss 1.0602454312213108
# Episode 6
# Epoch 18
# Loss 1.1188736021561596
# Episode 6
# Epoch 19
# Loss 1.177473903223137
# Episode 7
# Epoch 0
# Loss 0.05869321959259569
# Episode 7
# Epoch 1
# Loss 0.11735330338795748
# Episode 7
# Epoch 2
# Loss 0.17598106651014675
# Episode 7
# Epoch 3
# Loss 0.23458671015666832
# Episode 7
# Epoch 4
# Loss 0.2931640967181277
# Episode 7
# Epoch 5
# Loss 0.3517139340542246
# Episode 7
# Epoch 6
# Loss 0.4102634178668173
# Episode 7
# Epoch 7
# Loss 0.4687920273097551
# Episode 7
# Epoch 8
# Loss 0.5273125477511529
# Episode 7
# Epoch 9
# Loss 0.5858309630326393
# Episode 7
# Epoch 10
# Loss 0.6443276608780049
# Episode 7
# Epoch 11
# Loss 0.7028191927956802
# Episode 7
# Epoch 12
# Loss 0.7613138580697522
# Episode 7
# Epoch 13
# Loss 0.8197847418650701
# Episode 7
# Epoch 14
# Loss 0.878266858179695
# Episode 7
# Epoch 15
# Loss 0.9367321965640539
# Episode 7
# Epoch 16
# Loss 0.995174461141185
# Episode 7
# Epoch 17
# Loss 1.0536248866730475
# Episode 7
# Epoch 18
# Loss 1.1120597839595459
# Episode 7
# Epoch 19
# Loss 1.1704971384404343
# Episode 8
# Epoch 0
# Loss 0.05858340755960492
# Episode 8
# Epoch 1
# Loss 0.11716339114968863
# Episode 8
# Epoch 2
# Loss 0.17573546165369142
# Episode 8
# Epoch 3
# Loss 0.23430359914888926
# Episode 8
# Epoch 4
# Loss 0.2928679475513534
# Episode 8
# Epoch 5
# Loss 0.35142900815385286
# Episode 8
# Epoch 6
# Loss 0.40999284639546724
# Episode 8
# Epoch 7
# Loss 0.4685501345198288
# Episode 11
# Epoch 0
# Loss 0.057895577392900216
# Episode 11
# Epoch 1
# Loss 0.11579094971469785
# Episode 11
# Epoch 2
# Loss 0.1736842034252756
# Episode 11
# Epoch 3
# Loss 0.2315780639941855
# Episode 11
# Epoch 4
# Loss 0.2894696419481058
# Episode 11
# Epoch 5
# Loss 0.3473598993998968
# Episode 11
# Epoch 6
# Loss 0.40524744244658223
# Episode 11
# Epoch 7
# Loss 0.46313606974030896
# Episode 11
# Epoch 8
# Loss 0.521022634068179
# Episode 11
# Epoch 9
# Loss 0.5789086241200789
# Episode 11
# Epoch 10
# Loss 0.6367914986184772
# Episode 11
# Epoch 11
# Loss 0.6946746854859953
# Episode 11
# Epoch 12
# Loss 0.7525569265791896
# Episode 11
# Epoch 13
# Loss 0.8104381853935577
# Episode 11
# Epoch 14
# Loss 0.8683172909567061
# Episode 11
# Epoch 15
# Loss 0.9261955611931452
# Episode 11
# Epoch 16
# Loss 0.9840724267091524
# Episode 11
# Epoch 17
# Loss 1.0419468855576317
# Episode 11
# Epoch 18
# Loss 1.099819945613459
# Episode 11
# Epoch 19
# Loss 1.1576933348059268
# Episode 12
# Epoch 0
# Loss 0.05857722921488441
# Episode 12
# Epoch 1
# Loss 0.1171461378232898
# Episode 12
# Epoch 2
# Loss 0.17574308239550235
# Episode 12
# Epoch 3
# Loss 0.2343135881542324
# Episode 12
# Epoch 4
# Loss 0.2928887006452429
# Episode 12
# Epoch 5
# Loss 0.3514443699061592
# Episode 12
# Epoch 6
# Loss 0.41000570316459534
# Episode 12
# Epoch 7
# Loss 0.4685572565298214
# Episode 12
# Epoch 8
# Loss 0.5271137229541195
# Episode 12
# Epoch 9
# Loss 0.5856872084959646
# Episode 12
# Epoch 10
# Loss 0.6442335390947133
# Episode 12
# Epoch 11
# Loss 0.7028038587142652
# Episode 12
# Epoch 12
# Loss 0.7613629632098513
# Episode 12
# Epoch 13
# Loss 0.8199114781273442
# Episode 12
# Epoch 14
# Loss 0.8784579322107624
# Episode 12
# Epoch 15
# Loss 0.9369935789171641
# Episode 12
# Epoch 16
# Loss 0.9955340966390811
# Episode 12
# Epoch 17
# Loss 1.0540825905173878
# Episode 12
# Epoch 18
# Loss 1.1126313931665548
# Episode 12
# Epoch 19
# Loss 1.1711654481277844
# Episode 13
# Epoch 0
# Loss 0.05837496191263199
# Episode 13
# Epoch 1
# Loss 0.11674266202618247
# Episode 13
# Epoch 2
# Loss 0.1751084283091452
# Episode 13
# Epoch 3
# Loss 0.2334718732762596
# Episode 13
# Epoch 4
# Loss 0.29184207621313957
# Episode 13
# Epoch 5
# Loss 0.3502097942599136
# Episode 13
# Epoch 6
# Loss 0.4085684112086892
# Episode 13
# Epoch 7
# Loss 0.46692761549807116
# Episode 13
# Epoch 8
# Loss 0.5252875254691943
# Episode 13
# Epoch 9
# Loss 0.5836422768040843
# Episode 13
# Epoch 10
# Loss 0.6419982008182484
# Episode 13
# Epoch 11
# Loss 0.7003515517452489
# Loss 1.3270118284970522
# Episode 24
# Epoch 0
# Loss 0.06573451027982179
# Episode 24
# Epoch 1
# Loss 0.13142828355275787
# Episode 24
# Epoch 2
# Loss 0.19708576236024788
# Episode 24
# Epoch 3
# Loss 0.2627092815702278
# Episode 24
# Epoch 4
# Loss 0.3283010490809931
# Episode 24
# Epoch 5
# Loss 0.39386185318569517
# Episode 24
# Epoch 6
# Loss 0.45939649137432964
# Episode 24
# Epoch 7
# Loss 0.5249044702913347
# Episode 24
# Epoch 8
# Loss 0.5903858808402302
# Episode 24
# Epoch 9
# Loss 0.6558439105419245
# Episode 24
# Epoch 10
# Loss 0.7212821053900227
# Episode 24
# Epoch 11
# Loss 0.7866987094612989
# Episode 24
# Epoch 12
# Loss 0.8520986532217161
# Episode 24
# Epoch 13
# Loss 0.9174790975575378
# Episode 24
# Epoch 14
# Loss 0.982841414662951
# Episode 24
# Epoch 15
# Loss 1.048189006484321
# Episode 24
# Epoch 16
# Loss 1.1135225530601154
# Episode 24
# Epoch 17
# Loss 1.1788432739361252
# Episode 24
# Epoch 18
# Loss 1.244148068801856
# Episode 24
# Epoch 19
# Loss 1.3094412534503712
# Episode 25
# Epoch 0
# Loss 0.06501883731112568
# Episode 25
# Epoch 1
# Loss 0.1300340480487281
# Episode 25
# Epoch 2
# Loss 0.19505234425631138
# Episode 25
# Epoch 3
# Loss 0.2600301955134497
# Episode 25
# Epoch 4
# Loss 0.32500821298688926
# Episode 25
# Epoch 5
# Loss 0.38996722148645907
# Episode 25
# Epoch 6
# Loss 0.45494656221035423
# Episode 25
# Epoch 7
# Loss 0.5199177496545359
# Episode 25
# Epoch 8
# Loss 0.5848769128869433
# Episode 25
# Epoch 9
# Loss 0.6498813046569671
# Episode 25
# Epoch 10
# Loss 0.7148462232236469
# Episode 25
# Epoch 11
# Loss 0.7798436394046753
# Episode 25
# Epoch 12
# Loss 0.8448339500353423
# Episode 25
# Epoch 13
# Loss 0.9097845730499937
# Episode 25
# Epoch 14
# Loss 0.974750261917847
# Episode 25
# Epoch 15
# Loss 1.0396558794953408
# Episode 25
# Epoch 16
# Loss 1.1046142232185656
# Episode 25
# Epoch 17
# Loss 1.169571553450932
# Episode 25
# Epoch 18
# Loss 1.234495288543745
# Episode 25
# Epoch 19
# Loss 1.2994513665864227
# Episode 26
# Epoch 0
# Loss 0.06539550498827522
# Episode 26
# Epoch 1
# Loss 0.1307834666776172
# Episode 26
# Epoch 2
# Loss 0.19616193077723745
# Episode 26
# Epoch 3
# Loss 0.26155586695773686
# Episode 26
# Epoch 4
# Loss 0.32692996100034327
# Episode 26
# Epoch 5
# Loss 0.39231512349839315
# Episode 26
# Epoch 6
# Loss 0.4576950873742361
# Episode 26
# Epoch 7
# Loss 0.5230650991108122
# Episode 26
# Epoch 8
# Loss 0.5884284452886462
# Episode 26
# Epoch 9
# Loss 0.6537855721263912
# Episode 26
# Epoch 10
# Loss 0.7191365902692499
# Episode 26
# Epoch 11
# Loss 0.7844986758823033
# Episode 31
# Epoch 16
# Loss 1.112770907117306
# Episode 31
# Epoch 17
# Loss 1.1782245298849248
# Episode 31
# Epoch 18
# Loss 1.2436695680577141
# Episode 31
# Epoch 19
# Loss 1.3091268332862886
# Episode 32
# Epoch 0
# Loss 0.06543857341772583
# Episode 32
# Epoch 1
# Loss 0.1308951377262655
# Episode 32
# Epoch 2
# Loss 0.19635280576687664
# Episode 32
# Epoch 3
# Loss 0.26180754015732505
# Episode 32
# Epoch 4
# Loss 0.3272476218104975
# Episode 32
# Epoch 5
# Loss 0.3926894575523289
# Episode 32
# Epoch 6
# Loss 0.45812656811425745
# Episode 32
# Epoch 7
# Loss 0.5235589940837674
# Episode 32
# Epoch 8
# Loss 0.5890005068225174
# Episode 32
# Epoch 9
# Loss 0.6544356486673965
# Episode 32
# Epoch 10
# Loss 0.7198611306941953
# Episode 32
# Epoch 11
# Loss 0.7853038775119038
# Episode 32
# Epoch 12
# Loss 0.8507411950730324
# Episode 32
# Epoch 13
# Loss 0.9161740550340779
# Episode 32
# Epoch 14
# Loss 0.9816268527200955
# Episode 32
# Epoch 15
# Loss 1.047061344221145
# Episode 32
# Epoch 16
# Loss 1.1124884141943967
# Episode 32
# Epoch 17
# Loss 1.1779225978263566
# Episode 32
# Epoch 18
# Loss 1.2433500636340284
# Episode 32
# Epoch 19
# Loss 1.308770052981818
# Episode 33
# Epoch 0
# Loss 0.06539373731965559
# Episode 33
# Epoch 1
# Loss 0.1307821534894926
# Episode 33
# Epoch 2
# Loss 0.19617478085934137
# Episode 33
# Epoch 3
# Loss 0.26156535018570926
# Episode 33
# Epoch 4
# Loss 0.32695744869561055
# Episode 33
# Epoch 5
# Loss 0.3923448993647201
# Episode 33
# Epoch 6
# Loss 0.4577284177638351
# Episode 33
# Epoch 7
# Loss 0.5231147533546646
# Episode 33
# Epoch 8
# Loss 0.5885021942277485
# Episode 33
# Epoch 9
# Loss 0.6538872158179642
# Episode 33
# Epoch 10
# Loss 0.7192803840900457
# Episode 33
# Epoch 11
# Loss 0.7846615275159513
# Episode 33
# Epoch 12
# Loss 0.8500449077759343
# Episode 33
# Epoch 13
# Loss 0.9154244253270404
# Episode 33
# Epoch 14
# Loss 0.9808043642151888
# Episode 33
# Epoch 15
# Loss 1.0461843777579214
# Episode 33
# Epoch 16
# Loss 1.1115658217333637
# Episode 33
# Epoch 17
# Loss 1.1769433036744128
# Episode 33
# Epoch 18
# Loss 1.2423246525251361
# Episode 33
# Epoch 19
# Loss 1.3077004632081897
# Episode 34
# Epoch 0
# Loss 0.06526948948107336
# Episode 34
# Epoch 1
# Loss 0.13055579685538576
# Episode 34
# Epoch 2
# Loss 0.19583373448501032
# Episode 34
# Epoch 3
# Loss 0.2611013258928838
# Episode 34
# Epoch 4
# Loss 0.3263758273687268
# Episode 34
# Epoch 5
# Loss 0.3916370087708144
# Episode 34
# Epoch 6
# Loss 0.45693025831808
# Episode 34
# Epoch 7
# Loss 0.5221945219862181
# Episode 39
# Epoch 12
# Loss 0.843943777536325
# Episode 39
# Epoch 13
# Loss 0.9088486324964884
# Episode 39
# Epoch 14
# Loss 0.9737645568284952
# Episode 39
# Epoch 15
# Loss 1.0386750968852343
# Episode 39
# Epoch 16
# Loss 1.1035823038794634
# Episode 39
# Epoch 17
# Loss 1.1684887957826091
# Episode 39
# Epoch 18
# Loss 1.2334079588820015
# Episode 39
# Epoch 19
# Loss 1.2983168858962741
# Episode 40
# Epoch 0
# Loss 0.06517854897361813
# Episode 40
# Epoch 1
# Loss 0.13000652442375818
# Episode 40
# Epoch 2
# Loss 0.19451400191720689
# Episode 40
# Epoch 3
# Loss 0.2596841703046753
# Episode 40
# Epoch 4
# Loss 0.3245957289643661
# Episode 40
# Epoch 5
# Loss 0.3897378682299997
# Episode 40
# Epoch 6
# Loss 0.45477163477452714
# Episode 40
# Epoch 7
# Loss 0.5203172130830059
# Episode 40
# Epoch 8
# Loss 0.5848711592267559
# Episode 40
# Epoch 9
# Loss 0.6493622199491118
# Episode 40
# Epoch 10
# Loss 0.7139969321551046
# Episode 40
# Epoch 11
# Loss 0.7786455825159345
# Episode 40
# Epoch 12
# Loss 0.8433884515267129
# Episode 40
# Epoch 13
# Loss 0.9083292041952261
# Episode 40
# Epoch 14
# Loss 0.9729081545250885
# Episode 40
# Epoch 15
# Loss 1.037464291290051
# Episode 40
# Epoch 16
# Loss 1.1020598219463018
# Episode 40
# Epoch 17
# Loss 1.167045970024033
# Episode 40
# Epoch 18
# Loss 1.2317752500789032
# Episode 40
# Epoch 19
# Loss 1.2966984080508202
# Episode 41
# Epoch 0
# Loss 0.06557783657141651
# Episode 41
# Epoch 1
# Loss 0.1311349374591373
# Episode 41
# Epoch 2
# Loss 0.19666840159334242
# Episode 41
# Epoch 3
# Loss 0.26227609485310194
# Episode 41
# Epoch 4
# Loss 0.3278475928818807
# Episode 41
# Epoch 5
# Loss 0.3934036312081541
# Episode 41
# Epoch 6
# Loss 0.4589631033401626
# Episode 41
# Epoch 7
# Loss 0.5245530387813536
# Episode 41
# Epoch 8
# Loss 0.5901377386180684
# Episode 41
# Epoch 9
# Loss 0.6556769145342211
# Episode 41
# Epoch 10
# Loss 0.7212490824361643
# Episode 41
# Epoch 11
# Loss 0.7867983411997557
# Episode 41
# Epoch 12
# Loss 0.8523864222612852
# Episode 41
# Epoch 13
# Loss 0.9179634699830785
# Episode 41
# Epoch 14
# Loss 0.9834973886221027
# Episode 41
# Epoch 15
# Loss 1.0490143280476332
# Episode 41
# Epoch 16
# Loss 1.1145627103396691
# Episode 41
# Epoch 17
# Loss 1.1801431059332874
# Episode 41
# Epoch 18
# Loss 1.2456669685586046
# Episode 41
# Epoch 19
# Loss 1.3112490630398195
# Episode 42
# Epoch 0
# Loss 0.06456108595736902
# Episode 42
# Epoch 1
# Loss 0.12908075432534571
# Episode 42
# Epoch 2
# Loss 0.19361100029764752
# Episode 42
# Epoch 3
# Loss 0.25813909239991745
# Episode 42
# Epoch 4
# Loss 0.32267337801681223
# Episode 42
# Epoch 5
# Loss 0.38721519489129785
# Episode 42
# Epoch 6
# Loss 0.45183180497100056
# Episode 42
# Epoch 7
# Loss 0.5163474919569211
# Episode 42
# Epoch 8
# Loss 0.5808854802865974
# Episode 42
# Epoch 9
# Loss 0.6454049060716974
# Episode 42
# Epoch 10
# Loss 0.7099330271986197
# Episode 42
# Epoch 11
# Loss 0.7744840189990171
# Episode 42
# Epoch 12
# Loss 0.839021063136934
# Episode 42
# Epoch 13
# Loss 0.903569439633025
# Episode 42
# Epoch 14
# Loss 0.9680947940106746
# Episode 42
# Epoch 15
# Loss 1.0326294099993578
# Episode 42
# Epoch 16
# Loss 1.0971556079984714
# Episode 42
# Epoch 17
# Loss 1.1616963432593779
# Episode 42
# Epoch 18
# Loss 1.2262038331767324
# Episode 42
# Epoch 19
# Loss 1.2907066864184158
# Episode 43
# Epoch 0
# Loss 0.06398374681133467
# Episode 43
# Epoch 1
# Loss 0.1279645633111973
# Episode 43
# Epoch 2
# Loss 0.19193451392748193
# Episode 43
# Epoch 3
# Loss 0.25591827782635723
# Episode 43
# Epoch 4
# Loss 0.3198936441983624
# Episode 43
# Epoch 5
# Loss 0.38386895959863737
# Episode 43
# Epoch 6
# Loss 0.4478422646464719
# Episode 43
# Epoch 7
# Loss 0.5118195982720299
# Episode 43
# Epoch 8
# Loss 0.5757912544707207
# Episode 43
# Epoch 9
# Loss 0.6397582429228937
# Episode 43
# Epoch 10
# Loss 0.7037350470974328
# Episode 43
# Epoch 11
# Loss 0.7677053733768706
# Episode 43
# Epoch 12
# Loss 0.8316751686100771
# Episode 43
# Epoch 13
# Loss 0.8956466239809014
# Episode 43
# Epoch 14
# Loss 0.9596284349549853
# Episode 43
# Epoch 15
# Loss 1.0235983976667338
# Episode 43
# Epoch 16
# Loss 1.0875673161899337
# Episode 43
# Epoch 17
# Loss 1.151533270967885
# Episode 43
# Epoch 18
# Loss 1.215497009470233
# Episode 43
# Epoch 19
# Loss 1.2794595282637427
# Episode 44
# Epoch 0
# Loss 0.06336949456579469
# Episode 44
# Epoch 1
# Loss 0.12672668007395133
# Episode 44
# Epoch 2
# Loss 0.19010039321789196
# Episode 44
# Epoch 3
# Loss 0.2535113634156256
# Episode 44
# Epoch 4
# Loss 0.3168534137677915
# Episode 44
# Epoch 5
# Loss 0.38022561117621334
# Episode 44
# Epoch 6
# Loss 0.44357289229760527
# Episode 44
# Epoch 7
# Loss 0.5069280392610757
# Episode 44
# Epoch 8
# Loss 0.570308441260091
# Episode 44
# Epoch 9
# Loss 0.6336814672646016
# Episode 44
# Epoch 10
# Loss 0.6970456063803606
# Episode 44
# Epoch 11
# Loss 0.7604012725802524
# Episode 44
# Epoch 12
# Loss 0.8237403929514554
# Episode 44
# Epoch 13
# Loss 0.887111266830069
# Episode 44
# Epoch 14
# Loss 0.9504280093503346
# Episode 44
# Epoch 15
# Loss 1.013768775593329
# Episode 44
# Epoch 16
# Loss 1.0771006663883875
# Episode 44
# Epoch 17
# Loss 1.1404462846614227
# Episode 44
# Epoch 18
# Loss 1.203801956698138
# Episode 44
# Epoch 19
# Loss 1.2671501481271317
# Episode 45
# Epoch 0
# Loss 0.06349035239060206
# Episode 45
# Epoch 1
# Loss 0.12700331985703034
# Episode 45
# Epoch 2
# Loss 0.1905046899517744
# Episode 45
# Epoch 3
# Loss 0.2540106235821199
# Episode 45
# Epoch 4
# Loss 0.31753728550436094
# Episode 45
# Epoch 5
# Loss 0.3810671980516827
# Episode 45
# Epoch 6
# Loss 0.44456150562835794
# Episode 45
# Epoch 7
# Loss 0.5080685614508567
# Episode 45
# Epoch 8
# Loss 0.5715592944121669
# Episode 45
# Epoch 9
# Loss 0.6350672743540958
# Episode 45
# Epoch 10
# Loss 0.6985743911490119
# Episode 45
# Epoch 11
# Loss 0.7620665428273352
# Episode 45
# Epoch 12
# Loss 0.8255672061891464
# Episode 45
# Epoch 13
# Loss 0.8890791514551618
# Episode 45
# Epoch 14
# Loss 0.952589394029821
# Episode 45
# Epoch 15
# Loss 1.0161116504594958
# Episode 45
# Epoch 16
# Loss 1.079614265591621
# Episode 45
# Epoch 17
# Loss 1.1431076826658306
# Episode 45
# Epoch 18
# Loss 1.20660020094846
# Episode 45
# Epoch 19
# Loss 1.2700809737275667
# Episode 46
# Epoch 0
# Loss 0.06349644884111205
# Episode 46
# Epoch 1
# Loss 0.12700940996622015
# Episode 46
# Epoch 2
# Loss 0.19048908160655362
# Episode 46
# Epoch 3
# Loss 0.25397609318992137
# Episode 46
# Epoch 4
# Loss 0.3174641927834719
# Episode 46
# Epoch 5
# Loss 0.3809449236816282
# Episode 46
# Epoch 6
# Loss 0.444433206686406
# Episode 46
# Epoch 7
# Loss 0.5079237317879963
# Episode 46
# Epoch 8
# Loss 0.5714084405843525
# Episode 46
# Epoch 9
# Loss 0.6348931014620859
# Episode 46
# Epoch 10
# Loss 0.6983716375829213
# Episode 46
# Epoch 11
# Loss 0.7618636205365323
# Episode 46
# Epoch 12
# Loss 0.825344313303851
# Episode 46
# Epoch 13
# Loss 0.8888281463129315
# Episode 46
# Epoch 14
# Loss 0.9523112975108395
# Episode 46
# Epoch 15
# Loss 1.0157872979546998
# Episode 46
# Epoch 16
# Loss 1.0792762201196353
# Episode 46
# Epoch 17
# Loss 1.1427577285060457
# Episode 46
# Epoch 18
# Loss 1.2062369060649234
# Episode 46
# Epoch 19
# Loss 1.269712539158382
# Episode 47
# Epoch 0
# Loss 0.06339668363251874
# Episode 47
# Epoch 1
# Loss 0.12677824755516434
# Episode 47
# Epoch 2
# Loss 0.19014944125527927
# Episode 47
# Epoch 3
# Loss 0.25353940052651325
# Episode 47
# Epoch 4
# Loss 0.3169053062452875
# Episode 47
# Epoch 5
# Loss 0.38029043136854507
# Episode 47
# Epoch 6
# Loss 0.44364582570307615
# Episode 47
# Epoch 7
# Loss 0.507007153247315
# Episode 47
# Epoch 8
# Loss 0.5703868245354663
# Episode 47
# Epoch 9
# Loss 0.6337661997312768
# Episode 47
# Epoch 10
# Loss 0.6971270225669183
# Episode 47
# Epoch 11
# Loss 0.7604866076912857
# Episode 47
# Epoch 12
# Loss 0.8238605849515631
# Episode 47
# Epoch 13
# Loss 0.8872206318754515
# Episode 47
# Epoch 14
# Loss 0.9505720431113988
# Episode 47
# Epoch 15
# Loss 1.0139360291430957
# Episode 47
# Epoch 16
# Loss 1.0773014051832128
# Episode 47
# Epoch 17
# Loss 1.1406945100299297
# Episode 47
# Epoch 18
# Loss 1.2040634582140148
# Episode 47
# Epoch 19
# Loss 1.2674506638790488
# Episode 48
# Epoch 0
# Loss 0.0632895273466905
# Episode 48
# Epoch 1
# Loss 0.1265994534980167
# Episode 48
# Epoch 2
# Loss 0.1899159528044137
# Episode 48
# Epoch 3
# Loss 0.25322056969909956
# Episode 48
# Epoch 4
# Loss 0.3165290511873635
# Episode 48
# Epoch 5
# Loss 0.37982987840067256
# Episode 48
# Epoch 6
# Loss 0.4431135760970188
# Episode 48
# Epoch 7
# Loss 0.5064168926531618
# Episode 48
# Epoch 8
# Loss 0.5697299147555323
# Episode 48
# Epoch 9
# Loss 0.6330041597557791
# Episode 48
# Epoch 10
# Loss 0.6963255787256992
# Episode 48
# Epoch 11
# Loss 0.759625446362929
# Episode 48
# Epoch 12
# Loss 0.8229035987411485
# Episode 48
# Epoch 13
# Loss 0.8861777358795657
# Episode 48
# Epoch 14
# Loss 0.9495035658641295
# Episode 48
# Epoch 15
# Loss 1.0128011977401647
# Episode 48
# Epoch 16
# Loss 1.076087402173064
# Episode 48
# Epoch 17
# Loss 1.1393734009473613
# Episode 48
# Epoch 18
# Loss 1.2026602364534682
# Episode 48
# Epoch 19
# Loss 1.2659747753360056
# Episode 49
# Epoch 0
# Loss 0.06303478803857344
# Episode 49
# Epoch 1
# Loss 0.12616481650273495
# Episode 49
# Epoch 2
# Loss 0.18934064719870916
# Episode 49
# Epoch 3
# Loss 0.2524171838906528
# Episode 49
# Epoch 4
# Loss 0.3155784902475333
# Episode 49
# Epoch 5
# Loss 0.37870514365178615
# Episode 49
# Epoch 6
# Loss 0.4417385157320767
# Episode 49
# Epoch 7
# Loss 0.5048403008547386
# Episode 49
# Epoch 8
# Loss 0.5680595309539441
# Episode 49
# Epoch 9
# Loss 0.6311504004245906
# Episode 49
# Epoch 10
# Loss 0.6941902236055619
# Episode 49
# Epoch 11
# Loss 0.7573582356933019
# Episode 49
# Epoch 12
# Loss 0.8203952559190822
# Episode 49
# Epoch 13
# Loss 0.8834510546613162
# Episode 49
# Epoch 14
# Loss 0.9466545122286015
# Episode 49
# Epoch 15
# Loss 1.0097783924687527
# Episode 49
# Epoch 16
# Loss 1.072839996553069
# Episode 49
# Epoch 17
# Loss 1.135908745821788
# Episode 49
# Epoch 18
# Loss 1.1990227618200087
# Episode 49
# Epoch 19
# Loss 1.262137985433168
# test
