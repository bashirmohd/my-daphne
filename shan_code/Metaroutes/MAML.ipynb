# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd gdrive/My\ Drive/Codes/Metaroutes_exp8/
# Out:
# /content/gdrive/My Drive/Codes/Metaroutes_exp8

# %%
# %ls
# Out:
# MAML.ipynb       policies.py         results_topo2.xlsx  savemodels_topo2/
# MAML_test.ipynb  __pycache__/        savemodels/         test.py
# MetaRL/          results.csv         savemodels0812/     test_results.csv
# metaroute.py     results_topo1.xlsx  savemodels_topo1/

# %%
pip install Cython

# %%
pip install cherry-rl
# Out:
# ...
#      |████████████████████████████████| 40kB 3.0MB/s
# ...
#   Created wheel for cherry-rl: filename=cherry_rl-0.1.4-cp36-none-any.whl size=57843 sha256=7011672faee3f312aba7dc61722bec9771f2eb650a548aad64ca3c802ff410a0
#   Stored in directory: /root/.cache/pip/wheels/5f/cc/9e/54f8e0c8adbae7287df28415183c2c5539a33811c0a270b309
# Successfully built cherry-rl
# ...

# %%
# !python metaroute.py
# Out:
# adapt_lr 0.005
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# packet loss 107
# average_delivery_time 25.02513616557734
# adaptation_reward -45.609831611865495
# metaroute.py:276: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python metaroute.py
# Out:
# adapt_lr 0.005
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# packet loss 107
# average_delivery_time 25.02513616557734
# adaptation_reward -45.609831611865495
# metaroute.py:276: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python metaroute.py
# Out:
# adapt_lr 0.005
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# packet loss 340
# average_delivery_time 616.7994482436546
# adaptation_reward -127.5114271641717
# metaroute.py:262: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python metaroute.py
# Out:
# adapt_lr 0.005
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# packet loss 340
# average_delivery_time 102.82847360069893
# adaptation_reward -127.5114271641717
# metaroute.py:256: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python metaroute.py
# Out:
# adapt_lr 0.005
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# packet loss 362
# average_delivery_time 98.5875644205746
# adaptation_reward -139.6911220956047
# metaroute.py:256: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python metaroute.py
# Out:
# adapt_lr 0.005
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# packet loss 362
# average_delivery_time 98.5875644205746
# adaptation_reward -130.3314545807238
# metaroute.py:256: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python metaroute.py
# Out:
# adapt_lr 0.005
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# packet loss 343
# average_delivery_time 104.85316224690975
# adaptation_reward -127.69013015472835
# metaroute.py:252: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python metaroute.py
# Out:
# adapt_lr 0.005
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# packet loss 364
# average_delivery_time 116.11820726068402
# adaptation_reward -122.81337339542948
# metaroute.py:252: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python metaroute.py
# Out:
# adapt_lr 0.005
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# packet loss 336
# average_delivery_time 118.39894182083145
# adaptation_reward -115.59152552965311
# metaroute.py:233: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python metaroute.py
# Out:
# adapt_lr 0.005
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# packet loss 340
# average_delivery_time 126.08248603171855
# adaptation_reward -127.5114271641717
# metaroute.py:233: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python metaroute.py
# Out:
# adapt_lr 0.005
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# packet loss 0
# average_delivery_time 115.60489113612044
# adaptation_reward -115.15703815930264
# metaroute.py:233: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python metaroute.py
# Out:
# adapt_lr 0.005
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# packet loss 1
# average_delivery_time 114.20675560686907
# adaptation_reward -114.8872912219329
# metaroute.py:233: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python metaroute.py
# Out:
# adapt_lr 0.005
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# packet loss 0
# average_delivery_time 115.60489113612044
# adaptation_reward -115.15987091891252
# metaroute.py:233: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python metaroute.py
# Out:
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# packet loss 0
# average_delivery_time -93.14303389342889
# adaptation_reward -90.67143394586726
# metaroute.py:230: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python metaroute.py
# Out:
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# packet loss 1
# average_delivery_time 117.9765289449113
# adaptation_reward -31994.868490921705
# metaroute.py:230: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python metaroute.py
# Out:
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# packet loss 3
# average_delivery_time 118.6355582584606
# adaptation_reward -117.7472747259778
# metaroute.py:230: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python metaroute.py
# Out:
# adapt_lr 0.005
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# packet loss 0
# average_delivery_time 93.14303389342889
# adaptation_reward -90.68125540455928
# metaroute.py:233: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# ...

# %%
# !python metaroute.py
# Out:
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# adaptation_reward -53.63662053367157
# metaroute.py:235: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python metaroute.py
# Out:
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# adaptation_reward -25106.49740788016
# metaroute.py:252: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python metaroute.py
# Out:
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# adaptation_reward -29397.652172459104
# metaroute.py:252: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python metaroute.py
# Out:
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# adaptation_reward -27388.810794883837
# metaroute.py:233: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python metaroute.py
# Out:
# cuda
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
#
# Iteration 0
# adaptation_reward -27071.21085368963
# metaroute.py:252: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...
