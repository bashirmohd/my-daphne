# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd gdrive/My\ Drive/Codes/Deeproute/
# Out:
# /content/gdrive/My Drive/Codes/Deeproute

# %%
# %ls
# Out:
#  configs/                    deeproute_spa_agent.py      policies.py
#  deeproute.info.log         'Deeproute Timesheet.docx'   __pycache__/
#  Deeproute.ipynb             Dijkstra.py                 README.md
#  deeproute_random_agent.py   gym_deeproute_stat/
#  deeproute_rl_dqn_agent.py   Model.py

# %%
pip install cfg_load[all] --user
# Out:
# Collecting cfg_load[all]
#   Downloading https://files.pythonhosted.org/packages/a8/94/8e71b5ad8af827f42d89cdc30a2cd3934eef7368005d2a5d5f4eee4efb37/cfg_load-0.9.0-py3-none-any.whl
# Requirement already satisfied: pytz>=2018.4 in /usr/local/lib/python3.6/dist-packages (from cfg_load[all]) (2018.9)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from cfg_load[all]) (1.15.0)
# Collecting PyYAML>=4.2b1
#   Downloading https://files.pythonhosted.org/packages/64/c2/b80047c7ac2478f9501676c988a5411ed5572f35d1beff9cae07d321512c/PyYAML-5.3.1.tar.gz (269kB)
#      |████████████████████████████████| 276kB 4.0MB/s
# Collecting mpu[io]>=0.15.0
#   Downloading https://files.pythonhosted.org/packages/a6/3a/c4c04201c9cd8c5845f85915d644cb14b16200680e5fa424af01c411e140/mpu-0.23.1-py3-none-any.whl (69kB)
#      |████████████████████████████████| 71kB 7.0MB/s
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.6/dist-packages (from cfg_load[all]) (2.23.0)
# Requirement already satisfied: boto3; extra == "all" in /usr/local/lib/python3.6/dist-packages (from cfg_load[all]) (1.14.24)
# Requirement already satisfied: tzlocal; extra == "io" in /usr/local/lib/python3.6/dist-packages (from mpu[io]>=0.15.0->cfg_load[all]) (1.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->cfg_load[all]) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->cfg_load[all]) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->cfg_load[all]) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->cfg_load[all]) (2020.6.20)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3; extra == "all"->cfg_load[all]) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3; extra == "all"->cfg_load[all]) (0.3.3)
# Requirement already satisfied: botocore<1.18.0,>=1.17.24 in /usr/local/lib/python3.6/dist-packages (from boto3; extra == "all"->cfg_load[all]) (1.17.24)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.24->boto3; extra == "all"->cfg_load[all]) (2.8.1)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.24->boto3; extra == "all"->cfg_load[all]) (0.15.2)
# Building wheels for collected packages: PyYAML
#   Building wheel for PyYAML (setup.py) ... done
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44621 sha256=282bc31fe21667a7137f93a03fe4b5bc389f831cd7e5e689e0ebde40be3165aa
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
# Successfully built PyYAML
# Installing collected packages: PyYAML, mpu, cfg-load
#   WARNING: The script cfg_load is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed PyYAML-5.3.1 cfg-load-0.9.0 mpu-0.23.1

# %%
# !python deeproute_spa_agent.py
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# 1098
# 1085
# Average reward -23.72619258973061
# Episode Finished  after 1000 timesteps

# %%
# !python deeproute_random_agent.py
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# 1098
# 724
# Average reward -86.12455749862677
# Episode Finished  after 1000 timesteps
