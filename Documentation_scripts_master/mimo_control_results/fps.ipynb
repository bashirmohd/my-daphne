# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from pylab import *
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})
# plt.rcParams["font.weight"] = "bold"
# plt.rcParams["axes.labelweight"] = "bold"
# rc('axes', linewidth=3)

# %%
df = pd.read_csv('fps.csv')

# %%
#pwd

# %%
df.head()
# Out:
#    Timesteps  95% Efficiency: (0.95)  75% Efficiency: (0.75)  \
# 0      19583                     105                      91
# 1      23898                     106                      95
# 2      25001                     108                      89
# 3      26389                     107                      89
# 4      26831                     108                      92
#
#    85% Efficiency: (0.85)
# 0                      94
# 1                      94
# 2                      96
# 3                     102
# 4                      96

# %%
df.plot("Timesteps",["75% Efficiency: (0.75)","85% Efficiency: (0.85)", "95% Efficiency: (0.95)"],figsize=(16,12))
plt.xlabel("Timesteps")
plt.ylabel('Frame per second (fsp)')
#plt.xlim([0.0011, 0.0077])
plt.legend(loc=0, prop={'size': 26})

# %%
# df.plot(x='Timesteps',y='ddpg_10',color='red')

# df.plot(x='Timesteps',y='ddpg_10',color='red')
