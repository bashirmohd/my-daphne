# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from pylab import *
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})
# plt.rcParams["font.weight"] = "bold"
# plt.rcParams["axes.labelweight"] = "bold"
# rc('axes', linewidth=3)

# %%
df = pd.read_csv('episode_length_mean.csv')

# %%
#pwd

# %%
df.head()
# Out:
#    Timesteps  75% Efficiency: (0.75)  85% Efficiency: (0.85)  \
# 0      19583              151.330002               37.000000
# 1      23898              139.039993               44.750000
# 2      25001              135.699997               53.444443
# 3      26389              132.089996               56.750000
# 4      26831              133.649994               62.053570
#
#    95% Efficiency: (0.95)
# 0              179.214279
# 1              131.117645
# 2              123.215912
# 3              107.610001
# 4               82.820000

# %%
df.plot("Timesteps",["75% Efficiency: (0.75)","85% Efficiency: (0.85)", "95% Efficiency: (0.95)"],figsize=(16,12))
plt.xlabel("Timestep")
plt.ylabel('Episode Length Mean')
plt.xlim([20000, 350000])
# #plt.legend(loc=0, prop={'size': 26})
# Out:
# (20000.0, 350000.0)

# %%
# df.plot(x='Timesteps',y='ddpg_10',color='red')

# df.plot(x='Timesteps',y='ddpg_10',color='red')
