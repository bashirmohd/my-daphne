# %%
#Learning Rate = 0.0001
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from pylab import *
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})
# plt.rcParams["font.weight"] = "bold"
# plt.rcParams["axes.labelweight"] = "bold"
# rc('axes', linewidth=3)

# %%
pwd
# Out:
# '/Users/bashirm/Dropbox/LAWRENCE BERKELEY LAB/Laser/laser_results'

# %%
df = pd.read_csv('reward_plots.csv')

# %%
df.head()
# Out:
#    Timesteps  75% Efficiency: (0.75)  85% Efficiency: (0.85)  \
# 0     2004.0             -420.000000             -235.714279
# 1     3813.0             -468.500000             -332.181824
# 2     5158.0             -423.363648             -358.153839
# 3     6605.0             -412.357147             -326.888886
# 4     8285.0             -409.684204             -357.772736
#
#    95% Efficiency: (0.95)
# 0             -331.666656
# 1             -307.200012
# 2             -347.909088
# 3             -329.866669
# 4             -271.909088

# %%
df.plot("Timesteps",["75% Efficiency: (0.75)","85% Efficiency: (0.85)", "95% Efficiency: (0.95)"],figsize=(16,12))
plt.xlabel("Timesteps")
plt.ylabel('Mean Reward')
plt.xlim([0, 400000])
# #plt.legend(loc=0, prop={'size': 26})
# Out:
# (0.0, 400000.0)

# %%
#df.plot(x='Timesteps',y='ddpg_10',color='red')

df.plot(x='Timesteps',y='ddpg_10',color='red')
