# %%
import pandas
import numpy as np
from pandas import Series
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
print('test')
# Out:
# test

# %%
pwd
# Out:
# '/home/controller/Documents/CodeRoom/sdwan-rl'

# %%
deterministic_trial = [
('Ticks:', 1, 'Action:', 1, 'Ob:', (1, 10.0, 5.09), 'R:', -1, 'Total Reward:', -1),
('Ticks:', 2, 'Action:', 1, 'Ob:', (1, 10.0, 3.3899999999999997), 'R:', -1, 'Total Reward:', -2),
('Ticks:', 3, 'Action:', 1, 'Ob:', (1, 10.0, 6.34), 'R:', -1, 'Total Reward:', -3),
('Ticks:', 4, 'Action:', 0, 'Ob:', (0, '4.94', 4.19), 'R:', -4, 'Total Reward:', -7),
('Ticks:', 5, 'Action:', 1, 'Ob:', (1, 10.0, 4.73), 'R:', -1, 'Total Reward:', -8),
('Ticks:', 6, 'Action:', 1, 'Ob:', (1, 10.0, 5.34), 'R:', -1, 'Total Reward:', -9),
('Ticks:', 7, 'Action:', 1, 'Ob:', (1, 10.0, 8.05), 'R:', -1, 'Total Reward:', -10),
('Ticks:', 8, 'Action:', 0, 'Ob:', (0, '7.76', 6.2), 'R:', 2, 'Total Reward:', -8),
('Ticks:', 9, 'Action:', 0, 'Ob:', (0, '6.36', 5.27), 'R:', 2, 'Total Reward:', -6),
('Ticks:', 10, 'Action:', 1, 'Ob:', (1, 10.0, 6.77), 'R:', -1, 'Total Reward:', -7),
('Ticks:', 11, 'Action:', 0, 'Ob:', (0, '5.92', 4.89), 'R:', -4, 'Total Reward:', -11),
('Ticks:', 12, 'Action:', 1, 'Ob:', (1, 10.0, 7.029999999999999), 'R:', -1, 'Total Reward:', -12),
('Ticks:', 13, 'Action:', 0, 'Ob:', (0, '4.80', 4.15), 'R:', -4, 'Total Reward:', -16),
('Ticks:', 14, 'Action:', 1, 'Ob:', (1, 10.0, 4.4), 'R:', -1, 'Total Reward:', -17),
('Ticks:', 15, 'Action:', 1, 'Ob:', (1, 10.0, 6.029999999999999), 'R:', -1, 'Total Reward:', -18),
('Ticks:', 16, 'Action:', 0, 'Ob:', (0, '7.21', 6.91), 'R:', 2, 'Total Reward:', -16),
('Ticks:', 17, 'Action:', 0, 'Ob:', (0, '4.68', 3.7800000000000002), 'R:', -4, 'Total Reward:', -20),
('Ticks:', 18, 'Action:', 1, 'Ob:', (1, 10.0, 6.720000000000001), 'R:', -1, 'Total Reward:', -21),
('Ticks:', 19, 'Action:', 0, 'Ob:', (0, '9.54', 8.15), 'R:', 2, 'Total Reward:', -19),
('Ticks:', 20, 'Action:', 0, 'Ob:', (0, '4.12', 3.51), 'R:', -4, 'Total Reward:', -23),
('Ticks:', 21, 'Action:', 1, 'Ob:', (1, 10.0, 2.5700000000000003), 'R:', -1, 'Total Reward:', -24),
('Ticks:', 22, 'Action:', 1, 'Ob:', (1, 10.0, 6.33), 'R:', -1, 'Total Reward:', -25),
('Ticks:', 23, 'Action:', 0, 'Ob:', (0, '8.97', 7.57), 'R:', 2, 'Total Reward:', -23),
('Ticks:', 24, 'Action:', 0, 'Ob:', (0, '6.57', 5.42), 'R:', 2, 'Total Reward:', -21),
('Ticks:', 25, 'Action:', 1, 'Ob:', (1, 10.0, 3.84), 'R:', -1, 'Total Reward:', -22),
('Ticks:', 26, 'Action:', 1, 'Ob:', (1, 10.0, 4.27), 'R:', -1, 'Total Reward:', -23),
('Ticks:', 27, 'Action:', 1, 'Ob:', (1, 10.0, 2.95), 'R:', -1, 'Total Reward:', -24),
('Ticks:', 28, 'Action:', 1, 'Ob:', (1, 10.0, 6.49), 'R:', -1, 'Total Reward:', -25),
('Ticks:', 29, 'Action:', 0, 'Ob:', (0, '6.90', 5.69), 'R:', 2, 'Total Reward:', -23),
('Ticks:', 30, 'Action:', 1, 'Ob:', (1, 10.0, 5.34), 'R:', -1, 'Total Reward:', -24)
]

# %%
random_trial = [
('Ticks:', 1, 'Action:', 0, 'Ob:', (0, '5.96', 5.09), 'R:', -4, 'Total Reward:', -4),
('Ticks:', 2, 'Action:', 1, 'Ob:', (1, 10.0, 3.3899999999999997), 'R:', -1, 'Total Reward:', -5),
('Ticks:', 3, 'Action:', 1, 'Ob:', (1, 10.0, 6.34), 'R:', -1, 'Total Reward:', -6),
('Ticks:', 4, 'Action:', 0, 'Ob:', (0, '5.08', 3.9299999999999997), 'R:', -4, 'Total Reward:', -10),
('Ticks:', 5, 'Action:', 1, 'Ob:', (1, 10.0, 4.73), 'R:', -1, 'Total Reward:', -11),
('Ticks:', 6, 'Action:', 1, 'Ob:', (1, 10.0, 5.34), 'R:', -1, 'Total Reward:', -12),
('Ticks:', 7, 'Action:', 1, 'Ob:', (1, 10.0, 8.05), 'R:', -1, 'Total Reward:', -13),
('Ticks:', 8, 'Action:', 1, 'Ob:', (1, 10.0, 6.2), 'R:', -1, 'Total Reward:', -14),
('Ticks:', 9, 'Action:', 1, 'Ob:', (1, 10.0, 5.27), 'R:', -1, 'Total Reward:', -15),
('Ticks:', 10, 'Action:', 1, 'Ob:', (1, 10.0, 6.77), 'R:', -1, 'Total Reward:', -16),
('Ticks:', 11, 'Action:', 1, 'Ob:', (1, 10.0, 4.89), 'R:', -1, 'Total Reward:', -17),
('Ticks:', 12, 'Action:', 0, 'Ob:', (0, '7.94', 7.029999999999999), 'R:', 2, 'Total Reward:', -15),
('Ticks:', 13, 'Action:', 0, 'Ob:', (0, '5.32', 4.11), 'R:', -4, 'Total Reward:', -19),
('Ticks:', 14, 'Action:', 1, 'Ob:', (1, 10.0, 4.4), 'R:', -1, 'Total Reward:', -20),
('Ticks:', 15, 'Action:', 0, 'Ob:', (0, '7.70', 6.02), 'R:', 2, 'Total Reward:', -18),
('Ticks:', 16, 'Action:', 0, 'Ob:', (0, '8.24', 6.92), 'R:', 2, 'Total Reward:', -16),
('Ticks:', 17, 'Action:', 0, 'Ob:', (0, '5.00', 4.11), 'R:', -4, 'Total Reward:', -20),
('Ticks:', 18, 'Action:', 0, 'Ob:', (0, '8.18', 6.720000000000001), 'R:', 2, 'Total Reward:', -18),
('Ticks:', 19, 'Action:', 0, 'Ob:', (0, '8.55', 8.15), 'R:', 2, 'Total Reward:', -16),
('Ticks:', 20, 'Action:', 1, 'Ob:', (1, 10.0, 2.41), 'R:', -1, 'Total Reward:', -17),
('Ticks:', 21, 'Action:', 0, 'Ob:', (0, '3.87', 3.83), 'R:', -4, 'Total Reward:', -21),
('Ticks:', 22, 'Action:', 1, 'Ob:', (1, 10.0, 6.33), 'R:', -1, 'Total Reward:', -22),
('Ticks:', 23, 'Action:', 1, 'Ob:', (1, 10.0, 7.57), 'R:', -1, 'Total Reward:', -23),
('Ticks:', 24, 'Action:', 0, 'Ob:', (0, '6.88', 5.42), 'R:', 2, 'Total Reward:', -21),
('Ticks:', 25, 'Action:', 0, 'Ob:', (0, '4.89', 4.53), 'R:', -4, 'Total Reward:', -25),
('Ticks:', 26, 'Action:', 1, 'Ob:', (1, 10.0, 4.27), 'R:', -1, 'Total Reward:', -26),
('Ticks:', 27, 'Action:', 1, 'Ob:', (1, 10.0, 2.95), 'R:', -1, 'Total Reward:', -27),
('Ticks:', 28, 'Action:', 1, 'Ob:', (1, 10.0, 6.49), 'R:', -1, 'Total Reward:', -28),
('Ticks:', 29, 'Action:', 1, 'Ob:', (1, 10.0, 5.69), 'R:', -1, 'Total Reward:', -29),
('Ticks:', 30, 'Action:', 0, 'Ob:', (0, '6.76', 5.34), 'R:', 2, 'Total Reward:', -27)
]

# %%
# import matplotlib.pyplot as plt 
# %matplotlib inline

# def draw_graph(data, title):
#     # x axis values 
#     x1 =  [float(x[1]) for x in data]
#     #print (x)
#     # corresponding y axis values 
#     y1 = [float(x[5][1]) for x in data]
#     #print (y)

#     # plotting the points  
#     #plt.plot(x, y) 
#     plt.plot(x1, y1, label = "Current BW Mbps")  

#     y2 = [float(x[5][2]) for x in data]
#     plt.plot(x1, y2, label = "Available BW Mbps")  
    
#     y3 = [float(x[7]) for x in data]

#     plt.plot(x1, y3, label = "Reward")
    
#     y4 = [6.0 for x in data]

#     plt.plot(x1, y4, label = "SLA BW Mpbs")


#     # naming the x axis 
#     plt.xlabel('Ticks') 
#     # naming the y axis 
#     #plt.ylabel('Link Throughput') 

#     # giving a title to my graph 
#     plt.title(title) 

#     # show a legend on the plot 
#     plt.legend() 

#     # function to show the plot 
#     plt.show() 

# draw_graph(deterministic_trial, 'Deterministic Trial')

# %%
#draw_graph(random_trial, 'random_trial')

# %%
# x axis values 
x1 =  [float(x[1]) for x in deterministic_trial]
#print (x)
# corresponding y axis values 
y1 = [float(x[9]) for x in deterministic_trial]
#print (y)

# plotting the points  
#plt.plot(x, y) 
plt.plot(x1, y1, label = "Deterministic Trial")  

y2 = [float(x[9]) for x in random_trial]
plt.plot(x1, y2, label = "Ramdom Trial")  


# naming the x axis 
plt.xlabel('Ticks') 
# naming the y axis 
#plt.ylabel('Link Throughput') 

# giving a title to my graph 
plt.title("Cumulative Reward") 

# show a legend on the plot 
plt.legend() 

# function to show the plot 
plt.show()

# %%
def draw_cumulative_score(filename,title):
    df = pandas.read_csv(filename, header=None)
    data = df.values
    # x axis values 
    x =  [float(x[0]) for x in data]
    #print (x)
    # corresponding y axis values 
    y = [float(x[1]) for x in data]
    #print (y)
    series = Series(y)
    print ('Min', series.min(), 'Max', series.max(), 'mean', series.mean())
    # plotting the points  
    plt.plot(x, y) 

    # naming the x axis 
    plt.xlabel('Episodes') 
    # naming the y axis 
    plt.ylabel('Cumulative Score per episode') 

    # giving a title to my graph 
    plt.title(title) 

    # show a legend on the plot 
    # plt.legend() 

    # function to show the plot 
    plt.show() 
draw_cumulative_score('dqn_score_card.csv', 'DQN Agent')
# Out:
# Min -8.0 Max 168.0 mean 11.58

# %%
draw_cumulative_score('random_score_card_100.csv', 'Random Agent')
# Out:
# Min -9.0 Max 34.0 mean 0.93

# %%
pwd
# Out:
# '/home/controller/Documents/CodeRoom/sdwan-rl'

# %%
draw_cumulative_score('dqn_stat_score_card_100.csv', 'DQN Statistical Agent')
# Out:
# Min -8.0 Max 168.0 mean 11.58

# %%
draw_cumulative_score('random_stat_score_card.csv', 'Random Statistical Agent')
# Out:
# Min -45.0 Max 9.0 mean -17.09

# %%
draw_cumulative_score('dqn_stat_score_card_1000.csv', 'DQN Statistical Agent 1000 run')

# %%
draw_cumulative_score('dqn_stat_score_card_100.csv', 'DQN Statistical Agent 100 run')
# Out:
# Min -3.0 Max 95.0 mean 43.42

# %%
draw_cumulative_score('random_stat_score_card_100.csv', 'RANDOM Statistical Agent 100 run')
# Out:
# Min -6.0 Max 48.0 mean 10.08

# %%
draw_cumulative_score('dqn_stat_score_card_1000.csv', 'DQN Statistical Agent 1000 run')
# Out:
# Min -8.0 Max 339.0 mean 71.218

# %%
draw_cumulative_score('dqn_stat_score_card_10000.csv', 'DQN Statistical Agent 10000 run')
# Out:
# Min -14.0 Max 339.0 mean 77.6478

# %%
draw_cumulative_score('dqn_stat_score_card_100.csv', 'DQN Statistical Agent 1000 run')
# Out:
# Min -8.0 Max 168.0 mean 11.58

# %%
draw_cumulative_score('dqn_stat_score_card_1000.csv', 'DQN Statistical Agent 1000 run')

# %%
def draw_cumulative_score_2(filename,title):
    df = pandas.read_csv(filename, header=None)
    data = df.values
    # x axis values 
    x =  [float(x[0]) for x in data]
    #print (x)
    # corresponding y axis values 
    y = [float(x[1])/x[2] for x in data]
    #print (y)

    # plotting the points  
    plt.plot(x, y) 

    # naming the x axis 
    plt.xlabel('Episodes') 
    # naming the y axis 
    plt.ylabel('Cumulative Score per timestep') 

    # giving a title to my graph 
    plt.title(title) 

    # show a legend on the plot 
    # plt.legend() 

    # function to show the plot 
    plt.show()

# %%
draw_cumulative_score_2('dqn_stat_score_card_1000.csv', 'DQN Statistical Agent 1000 run')

# %%
def draw_cumulative_score_3(filename,title):
    df = pandas.read_csv(filename, header=None)
    data = df.values
    # x axis values 
    x =  [float(x[0]) for x in data]
    #print (x)
    # corresponding y axis values 
    y = [float(x[2]) for x in data]
    #print (y)

    # plotting the points  
    plt.plot(x, y) 

    # naming the x axis 
    plt.xlabel('Episodes') 
    # naming the y axis 
    plt.ylabel('timestep per episode') 

    # giving a title to my graph 
    plt.title(title) 

    # show a legend on the plot 
    # plt.legend() 

    # function to show the plot 
    plt.show()

# %%
draw_cumulative_score_3('dqn_stat_score_card_1000.csv', 'DQN Statistical Agent 1000 run')

# %%
def draw_cumulative_score_4(filename,title):
    df = pandas.read_csv(filename, header=None)
    data = df.values[400:600]
    # x axis values 
    x =  [float(x[0]) for x in data]
    y = [float(x[1]) for x in data]
    # Tail-rolling average transform
    series = Series(y)
    rolling = series.rolling(window=3)
    rolling_mean = rolling.mean()
    print ('Min', series.min(), 'Max', series.max(), 'mean', series.mean())
    #print(rolling_mean.head(10))
    # plot original and transformed dataset
    #series.plot()
    plt.plot(x, rolling_mean, color='red') 
    plt.title(title) 
     # naming the x axis 
    plt.xlabel('Episodes') 
    # naming the y axis 
    plt.ylabel('Cumulative Score per timestep') 
    #rolling_mean.plot(color='red')
    plt.show()

# %%
draw_cumulative_score_4('dqn_stat_score_card_1000.csv', 'Rolling Mean of score')
# Out:
# Min -7.0 Max 272.0 mean 82.04

# %%
draw_cumulative_score('dqn_stat_score_card_10000.csv', 'DQN Statistical Agent 10000 run')

# %%
draw_cumulative_score_4('dqn_stat_score_card_10000.csv', 'DQN Statistical Agent 10000 run')

# %%
draw_cumulative_score_3('dqn_stat_score_card_10000.csv', 'DQN Statistical Agent 10000 run')

# %%
draw_cumulative_score('dqn_stat_play_score_card_100.csv', 'DQN Statistical Agent Play 100 run')

# %%
draw_cumulative_score('a3c_stat_play_score_card_100.csv', 'A3C Statistical Agent Play 100 run')
# Out:
# Min 83.0 Max 210.0 mean 148.61

# %%
draw_cumulative_score('a3c_play_score_card_100.csv', 'A3C Agent Play 100 run')

# %%
draw_cumulative_score_4('dqn_stat_play_score_card_100.csv', 'DQN Statistical Agent Play 1000 run')
# Out:
# Min -6.0 Max 255.0 mean 178.52

# %%
draw_cumulative_score('dqn_play_score_card_100.csv', 'DQN  Agent Play 100 run')
# Out:
# Min 21.0 Max 76.0 mean 54.18

# %%
draw_cumulative_score('random_score_card_100.csv', 'Random Agent')
# Out:
# Min -6.0 Max 56.0 mean 28.13

# %%
def draw_cumulative_score_5(filename1, filename2, label1, label2, title):
    plt.figure(figsize=(10,5))
    
    df1 = pandas.read_csv(filename1, header=None)
    data1 = df1.values
    df2 = pandas.read_csv(filename2, header=None)
    data2 = df2.values
    # x axis values 
    x =  [float(x[0]) for x in data1]
    #print (x)
    # corresponding y axis values 
    y1 = [float(x[1]) for x in data1]
    y2 = [float(x[1]) for x in data2]
  
    plt.plot(x, y1, label = label1) 
    plt.plot(x, y2, label = label2) 
    y3 = [np.mean(y1) for x in data1]
    plt.plot(x, y3, label = 'Mean score - ' + label1) 
    y4 = [np.mean(y2) for x in data1]
    plt.plot(x, y4, label = 'Mean score - ' + label2) 
    plt.ylabel('Cumulative Score per episode') 
    
    # naming the x axis 
    plt.xlabel('Episodes') 

    # giving a title to my graph 
    plt.title(title) 

    # show a legend on the plot 
    plt.legend() 

    # function to show the plot 
    plt.show() 
draw_cumulative_score_5('dqn_play_score_card_100.csv', 'random_score_card_100.csv', 'DQN Agent', 'Random Agent', 'DeepQ Agent vs Random')

# %%
draw_cumulative_score_4('dqn_play_score_card_100.csv', 'DQN  Agent Play 100 run')
# Out:
# Min 21.0 Max 76.0 mean 54.18

# %%
random_trial = [
('Ticks', 1, 'Action', 0, 'Ob', (0, '5.55', 3.4299999999999997), 'R', -1, 'Total Reward', -1),
('Ticks', 2, 'Action', 1, 'Ob', (1, 10.0, 6.34),'R', 0, 'Total Reward', -1),
('Ticks', 3, 'Action', 1, 'Ob', (1, 10.0, 3.75), 'R', 0, 'Total Reward', -1),
('Ticks', 4, 'Action', 0, 'Ob', (0, '6.65', 4.72), 'R', 3 ,'Total Reward', 2),
('Ticks', 5, 'Action', 1, 'Ob', (1, 10.0, 5.34), 'R', 0, 'Total Reward', 2),
('Ticks', 6, 'Action', 1, 'Ob', (1, 10.0, 8.05), 'R', 0, 'Total Reward', 2),
('Ticks', 7, 'Action', 1, 'Ob', (1, 10.0, 6.2), 'R', 0, 'Total Reward', 2),
('Ticks', 8, 'Action', 1, 'Ob', (1, 10.0, 5.27), 'R', 0, 'Total Reward', 2),
('Ticks', 9, 'Action', 1, 'Ob', (1, 10.0, 6.77), 'R', 0, 'Total Reward', 2),
('Ticks', 10, 'Action', 1, 'Ob', (1, 10.0, 4.89), 'R', 0, 'Total Reward', 2),
('Ticks', 11, 'Action', 1, 'Ob', (1, 10.0, 7.029999999999999), 'R', 0, 'Total Reward', 2),
('Ticks', 12, 'Action', 0, 'Ob', (0, '6.10', 4.09), 'R', 3, 'Total Reward', 5),
('Ticks', 13, 'Action', 0, 'Ob', (0, '6.49', 4.38), 'R', 3, 'Total Reward', 8),
('Ticks', 14, 'Action', 1, 'Ob', (1, 10.0, 6.02), 'R', 0, 'Total Reward', 8),
('Ticks', 15, 'Action', 0, 'Ob', (0, '9.15', 6.91), 'R', 3, 'Total Reward', 11),
('Ticks', 16, 'Action', 0, 'Ob', (0, '5.66', 3.66), 'R', -1, 'Total Reward', 10),
('Ticks', 17, 'Action', 0, 'Ob', (0, '9.02', 6.720000000000001),'R', 3, 'Total Reward', 13),
('Ticks', 18, 'Action', 0, 'Ob', (0, '10.4', 8.15), 'R', 3, 'Total Reward', 16),
('Ticks', 19, 'Action', 0, 'Ob', (0, '4.66', 2.8600000000000003), 'R', -1, 'Total Reward', 15),
('Ticks', 20, 'Action', 1, 'Ob', (1, 10.0, 2.5700000000000003), 'R', 0, 'Total Reward', 15),
('Ticks', 21, 'Action', 0, 'Ob', (0, '8.57', 6.33), 'R', 3, 'Total Reward', 18),
('Ticks', 22, 'Action', 1, 'Ob', (1, 10.0, 7.57), 'R', 0, 'Total Reward', 18),
('Ticks', 23, 'Action', 1, 'Ob', (1, 10.0, 5.42), 'R', 0, 'Total Reward', 18),
('Ticks', 24, 'Action', 0, 'Ob', (0, '5.84', 3.83), 'R', -1, 'Total Reward', 17),
('Ticks', 25, 'Action', 0, 'Ob', (0, '6.47', 4.27), 'R', 3, 'Total Reward', 20),
('Ticks', 26, 'Action', 1, 'Ob', (1, 10.0, 2.95), 'R', 0, 'Total Reward', 20),
('Ticks', 27, 'Action', 1, 'Ob', (1, 10.0, 6.49) ,'R', 0, 'Total Reward', 20),
('Ticks', 28, 'Action', 1, 'Ob', (1, 10.0, 5.69), 'R', 0, 'Total Reward', 20),
('Ticks', 29, 'Action', 1, 'Ob', (1, 10.0, 5.34), 'R', 0, 'Total Reward', 20),
('Ticks', 30 ,'Action', 0, 'Ob', (0, '11.0', 8.83), 'R', 3 ,'Total Reward', 23)
]

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

def draw_graph(data, title):
    plt.figure(figsize=(10,5))
    # x axis values 
    x1 =  [float(x[1]) for x in data]
    #print (x)
    # corresponding y axis values 
    y1 = [float(x[5][1]) for x in data]
    #print (y)

    # plotting the points  
    #plt.plot(x, y) 
    plt.plot(x1, y1, label = "Current BW Mbps")  

    y2 = [float(x[5][2]) for x in data]
    plt.plot(x1, y2, label = "Available BW Mbps")  
    
    y3 = [float(x[7]) for x in data]

    plt.plot(x1, y3, label = "Reward")
    
    y4 = [6.0 for x in data]

    plt.plot(x1, y4, label = "SLA BW Mpbs")
    
    y5 = [x[3] * 10 for x in data]

    plt.scatter(x1, y5, color='red',  
             marker='o',  label = "Action 0/1")
    


    # naming the x axis 
    plt.xlabel('Ticks') 
    # naming the y axis 
    #plt.ylabel('Link Throughput') 

    # giving a title to my graph 
    plt.title(title) 

    # show a legend on the plot 
    plt.legend() 

    # function to show the plot 
    plt.show() 

draw_graph(random_trial, 'Random Trial')

# %%
deterministic_trial = [
('Ticks', 1 , 'Action', 1 , 'Ob', (1, 10.0, 3.3899999999999997) , 'R', 0 , 'Total Reward', 0),
('Ticks', 2 , 'Action', 1 , 'Ob', (1, 10.0, 6.34) , 'R', 0 , 'Total Reward', 0),
('Ticks', 3 , 'Action', 0 , 'Ob', (0, '5.73', 3.7300000000000004) , 'R', -1 , 'Total Reward', -1),
('Ticks', 4 , 'Action', 1 , 'Ob', (1, 10.0, 4.73) , 'R', 0 , 'Total Reward', -1),
('Ticks', 5 , 'Action', 1 , 'Ob', (1, 10.0, 5.34) , 'R', 0 , 'Total Reward', -1),
('Ticks', 6 , 'Action', 1 , 'Ob', (1, 10.0, 8.05) , 'R', 0 , 'Total Reward', -1),
('Ticks', 7 , 'Action', 0 , 'Ob', (0, '8.19', 6.1899999999999995) , 'R', 3 , 'Total Reward', 2),
('Ticks', 8 , 'Action', 0 , 'Ob', (0, '7.30', 5.26) , 'R', 3 , 'Total Reward', 5),
('Ticks', 9 , 'Action', 1 , 'Ob', (1, 10.0, 6.77) , 'R', 0 , 'Total Reward', 5),
('Ticks', 10 , 'Action', 0 , 'Ob', (0, '6.96', 4.88) , 'R', 3 , 'Total Reward', 8),
('Ticks', 11 , 'Action', 1 , 'Ob', (1, 10.0, 7.029999999999999) , 'R', 0 , 'Total Reward', 8),
('Ticks', 12 , 'Action', 0 , 'Ob', (0, '6.19', 4.08) , 'R', 3 , 'Total Reward', 11),
('Ticks', 13 , 'Action', 1 , 'Ob', (1, 10.0, 4.39) , 'R', 0 , 'Total Reward', 11),
('Ticks', 14 , 'Action', 1 , 'Ob', (1, 10.0, 6.02) , 'R', 0 , 'Total Reward', 11),
('Ticks', 15 , 'Action', 0 , 'Ob', (0, '8.92', 6.91) , 'R', 3 , 'Total Reward', 14),
('Ticks', 16 , 'Action', 0 , 'Ob', (0, '5.61', 3.67) , 'R', -1 , 'Total Reward', 13),
('Ticks', 17 , 'Action', 1 , 'Ob', (1, 10.0, 6.720000000000001) , 'R', 0 , 'Total Reward', 13),
('Ticks', 18 , 'Action', 0 , 'Ob', (0, '10.4', 8.15) , 'R', 3 , 'Total Reward', 16),
('Ticks', 19 , 'Action', 0 , 'Ob', (0, '4.66', 2.8600000000000003) , 'R', -1 , 'Total Reward', 15),
('Ticks', 20 , 'Action', 1 , 'Ob', (1, 10.0, 2.5700000000000003) , 'R', 0 , 'Total Reward', 15),
('Ticks', 21 , 'Action', 1 , 'Ob', (1, 10.0, 6.33) , 'R', 0 , 'Total Reward', 15),
('Ticks', 22 , 'Action', 0 , 'Ob', (0, '9.64', 7.57) , 'R', 3 , 'Total Reward', 18),
('Ticks', 23 , 'Action', 0 , 'Ob', (0, '7.46', 5.42) , 'R', 3 , 'Total Reward', 21),
('Ticks', 24 , 'Action', 1 , 'Ob', (1, 10.0, 3.84) , 'R', 0 , 'Total Reward', 21),
('Ticks', 25 , 'Action', 1 , 'Ob', (1, 10.0, 4.27) , 'R', 0 , 'Total Reward', 21),
('Ticks', 26 , 'Action', 1 , 'Ob', (1, 10.0, 2.95) , 'R', 0 , 'Total Reward', 21),
('Ticks', 27 , 'Action', 1 , 'Ob', (1, 10.0, 6.49) , 'R', 0 , 'Total Reward', 21),
('Ticks', 28 , 'Action', 0 , 'Ob', (0, '7.80', 5.68) , 'R', 3 , 'Total Reward', 24),
('Ticks', 29 , 'Action', 1 , 'Ob', (1, 10.0, 5.34) , 'R', 0 , 'Total Reward', 24),
('Ticks', 30 , 'Action', 1 , 'Ob', (1, 10.0, 8.83) , 'R', 0 , 'Total Reward', 24)
]

# %%
# x axis values 
x1 =  [float(x[1]) for x in deterministic_trial]
#print (x)
# corresponding y axis values 
y1 = [float(x[9]) for x in deterministic_trial]
#print (y)

# plotting the points  
#plt.plot(x, y) 
plt.plot(x1, y1, label = "Deterministic Trial")  

y2 = [float(x[9]) for x in random_trial]
plt.plot(x1, y2, label = "Ramdom Trial")  


# naming the x axis 
plt.xlabel('Ticks') 
# naming the y axis 
#plt.ylabel('Link Throughput') 

# giving a title to my graph 
plt.title("Cumulative Reward") 

# show a legend on the plot 
plt.legend() 

# function to show the plot 
plt.show()

# %%
# Initial State: (0, '7.14', 5.09)
# Taking predicted  action 0                                    
# Ticks: 1 Action: 0 Ob: (0, '8.66', 6.5600000000000005) R: 3 Total Reward: 3
# Taking predicted  action 0                                     
# Ticks: 2 Action: 0 Ob: (0, '8.74', 6.63) R: 3 Total Reward: 6
# Taking predicted  action 0                                    
# Ticks: 3 Action: 0 Ob: (0, '8.52', 6.3) R: 3 Total Reward: 9
# Taking predicted  action 0                                     
# Ticks: 4 Action: 0 Ob: (0, '11.2', 8.83) R: 3 Total Reward: 12
# Taking predicted  action 0                                     
# Ticks: 5 Action: 0 Ob: (0, '6.92', 4.9) R: 3 Total Reward: 15
# Taking predicted  action 0                                     
# Ticks: 6 Action: 0 Ob: (0, '4.09', 2.26) R: -1 Total Reward: 14
# Taking predicted  action 1                                     
# Ticks: 7 Action: 1 Ob: (1, 10.0, 6.0600000000000005) R: 0 Total Reward: 14
# Taking predicted  action 0                                                    
# Ticks: 8 Action: 0 Ob: (0, '7.88', 5.77) R: 3 Total Reward: 17                                                                     [0/5855]
# Taking predicted  action 0                                   
# Ticks: 9 Action: 0 Ob: (0, '7.27', 5.24) R: 3 Total Reward: 20
# Taking predicted  action 0                                     
# Ticks: 10 Action: 0 Ob: (0, '8.03', 6.04) R: 3 Total Reward: 23 
# Taking predicted  action 0                                                
# Ticks: 11 Action: 0 Ob: (0, '5.66', 3.67) R: -1 Total Reward: 22
# Taking predicted  action 1                                                    
# Ticks: 12 Action: 1 Ob: (1, 10.0, 8.83) R: 0 Total Reward: 22              
# Taking predicted  action 0                                   
# Ticks: 13 Action: 0 Ob: (0, '5.98', 3.75) R: -1 Total Reward: 21
# Taking predicted  action 1                                     
# Ticks: 14 Action: 1 Ob: (1, 10.0, 2.92) R: 0 Total Reward: 21
# Taking predicted  action 0                                   
# Ticks: 15 Action: 0 Ob: (0, '8.32', 6.29) R: 3 Total Reward: 24
# Taking predicted  action 0                                   
# Ticks: 16 Action: 0 Ob: (0, '6.74', 4.79) R: 3 Total Reward: 27
# Taking predicted  action 0                                   
# Ticks: 17 Action: 0 Ob: (0, '10.6', 8.46) R: 3 Total Reward: 30
# Taking predicted  action 0         
# Ticks: 18 Action: 0 Ob: (0, '7.24', 5.24) R: 3 Total Reward: 33
# Taking predicted  action 0    
# Ticks: 19 Action: 0 Ob: (0, '4.34', 2.38) R: -1 Total Reward: 32                                          
# Taking predicted  action 1
# Ticks: 20 Action: 1 Ob: (1, 10.0, 4.81) R: 0 Total Reward: 32                                                                              
# Taking predicted  action 0                       
# Ticks: 21 Action: 0 Ob: (0, '7.40', 5.28) R: 3 Total Reward: 35
# Taking predicted  action 0                                                                                                                 
# Ticks: 22 Action: 0 Ob: (0, '10.3', 8.08) R: 3 Total Reward: 38
# Taking predicted  action 0      
# Ticks: 23 Action: 0 Ob: (0, '12.4', 0.0) R: 3 Total Reward: 41
# Taking predicted  action 0                                                 
# Ticks: 24 Action: 0 Ob: (0, '8.82', 6.71) R: 3 Total Reward: 44
# Taking predicted  action 0                                   
# Ticks: 25 Action: 0 Ob: (0, '12.5', 0.0) R: 3 Total Reward: 47
# Taking predicted  action 0                                  
# Ticks: 26 Action: 0 Ob: (0, '10.8', 8.52) R: 3 Total Reward: 50
# Taking predicted  action 0                                    
# Ticks: 27 Action: 0 Ob: (0, '8.83', 6.77) R: 3 Total Reward: 53
# Taking predicted  action 0                                   
# Ticks: 28 Action: 0 Ob: (0, '8.06', 5.92) R: 3 Total Reward: 56
# Taking predicted  action 0                                     
# Ticks: 29 Action: 0 Ob: (0, '7.25', 5.22) R: 3 Total Reward: 59
# Taking predicted  action 0                                                
# Ticks: 30 Action: 0 Ob: (0, '4.99', 2.7800000000000002) R: -1 Total Reward: 58
# Episode Aborted  after 30 timesteps

# %%
# Initial State: (0, '7.14', 5.09)
                             
deepq_play = [
    ('Ticks',  1 , 'Action',  0 , 'Ob',  (0, '8.66', 6.5600000000000005) , 'R',  3 , 'Total Reward',  3),                                    
    ('Ticks',  2 , 'Action',  0 , 'Ob',  (0, '8.74', 6.63) , 'R',  3 , 'Total Reward',  6),                                   
    ('Ticks',  3 , 'Action',  0 , 'Ob',  (0, '8.52', 6.3) , 'R',  3 , 'Total Reward',  9),                                 
    ('Ticks',  4 , 'Action',  0 , 'Ob',  (0, '11.2', 8.83) , 'R',  3 , 'Total Reward',  12),                                     
    ('Ticks',  5 , 'Action',  0 , 'Ob',  (0, '6.92', 4.9) , 'R',  3 , 'Total Reward',  15),                                 
    ('Ticks',  6 , 'Action',  0 , 'Ob',  (0, '4.09', 2.26) , 'R',  -1 , 'Total Reward',  14),                                    
    ('Ticks',  7 , 'Action',  1 , 'Ob',  (1, 10.0, 6.0600000000000005) , 'R',  0 , 'Total Reward',  14),                                                
    ('Ticks',  8 , 'Action',  0 , 'Ob',  (0, '7.88', 5.77) , 'R',  3 , 'Total Reward',  17),                                   
    ('Ticks',  9 , 'Action',  0 , 'Ob',  (0, '7.27', 5.24) , 'R',  3 , 'Total Reward',  20),                                     
    ('Ticks',  10 , 'Action',  0 , 'Ob',  (0, '8.03', 6.04) , 'R',  3 , 'Total Reward',  23),                                                
    ('Ticks',  11 , 'Action',  0 , 'Ob',  (0, '5.66', 3.67) , 'R',  -1 , 'Total Reward',  22),                                                   
    ('Ticks',  12 , 'Action',  1 , 'Ob',  (1, 10.0, 8.83) , 'R',  0 , 'Total Reward',  22 ),                                               
    ('Ticks',  13 , 'Action',  0 , 'Ob',  (0, '5.98', 3.75) , 'R',  -1 , 'Total Reward',  21  ),                                  
    ('Ticks',  14 , 'Action',  1 , 'Ob',  (1, 10.0, 2.92) , 'R',  0 , 'Total Reward',  21  ),                                 
    ('Ticks',  15 , 'Action',  0 , 'Ob',  (0, '8.32', 6.29) , 'R',  3 , 'Total Reward',  24 ),                                  
    ('Ticks',  16 , 'Action',  0 , 'Ob',  (0, '6.74', 4.79) , 'R',  3 , 'Total Reward',  27   ),                                
    ('Ticks',  17 , 'Action',  0 , 'Ob',  (0, '10.6', 8.46) , 'R',  3 , 'Total Reward',  30     ),    
    ('Ticks',  18 , 'Action',  0 , 'Ob',  (0, '7.24', 5.24) , 'R',  3 , 'Total Reward',  33    ),
    ('Ticks',  19 , 'Action',  0 , 'Ob',  (0, '4.34', 2.38) , 'R',  -1 , 'Total Reward',  32),
    ('Ticks',  20 , 'Action',  1 , 'Ob',  (1, 10.0, 4.81) , 'R',  0 , 'Total Reward',  32     ),                                                                                                
    ('Ticks',  21 , 'Action',  0 , 'Ob',  (0, '7.40', 5.28) , 'R',  3 , 'Total Reward',  35     ),                                                                                                            
    ('Ticks',  22 , 'Action',  0 , 'Ob',  (0, '10.3', 8.08) , 'R',  3 , 'Total Reward',  38      ),
    ('Ticks',  23 , 'Action',  0 , 'Ob',  (0, '12.4', 0.0) , 'R',  3 , 'Total Reward',  41         ),                                        
    ('Ticks',  24 , 'Action',  0 , 'Ob',  (0, '8.82', 6.71) , 'R',  3 , 'Total Reward',  44 ),                         
    ('Ticks',  25 , 'Action',  0 , 'Ob',  (0, '12.5', 0.0) , 'R',  3 , 'Total Reward',  47  ),                                
    ('Ticks',  26 , 'Action',  0 , 'Ob',  (0, '10.8', 8.52) , 'R',  3 , 'Total Reward',  50   ),                                 
    ('Ticks',  27 , 'Action',  0 , 'Ob',  (0, '8.83', 6.77) , 'R',  3 , 'Total Reward',  53     ),                              
    ('Ticks',  28 , 'Action',  0 , 'Ob',  (0, '8.06', 5.92) , 'R',  3 , 'Total Reward',  56       ),                              
    ('Ticks',  29 , 'Action',  0 , 'Ob',  (0, '7.25', 5.22) , 'R',  3 , 'Total Reward',  59         ),                                       
    ('Ticks',  30 , 'Action',  0 , 'Ob',  (0, '4.99', 2.7800000000000002) , 'R',  -1 , 'Total Reward',  58)
]

# %% [raw]
# # x axis values
# x1 =  [float(x[1]) for x in deterministic_trial]
# #print (x)
# # corresponding y axis values
# y1 = [float(x[9]) for x in deterministic_trial]
# #print (y)
#
# # plotting the points
# #plt.plot(x, y)
# plt.plot(x1, y1, label = "Deterministic Trial")
#
# y2 = [float(x[9]) for x in random_trial]
# plt.plot(x1, y2, label = "Ramdom Trial")
#
# y3 = [float(x[9]) for x in deepq_play]
# plt.plot(x1, y3, label = "DeepQ Play")
#
#
# # naming the x axis
# plt.xlabel('Ticks')
# # naming the y axis
# #plt.ylabel('Link Throughput')
#
# # giving a title to my graph
# plt.title("Cumulative Reward")
#
# # show a legend on the plot
# plt.legend()
#
# # function to show the plot
# plt.show()

# %%
draw_graph(deepq_play, 'DeepQ Play')

# %%
def draw_cumulative_score_6(filenames, labels):
    plt.figure(figsize=(16,8))
    
    for idx, filename in enumerate(filenames):
        df = pandas.read_csv(filename, header=None)
        data = df.values
        x =  [float(x[0]) for x in data]
        y = [float(x[1]) for x in data]
        label = labels[idx]
        y_mean = [np.mean(y) for x in data]
        plt.plot(x, y, label = labels[idx]) 
        plt.plot(x, y_mean, label = 'Mean score - ' + label)
        

    # naming the x axis 
    plt.xlabel('Episodes') 

    # show a legend on the plot 
    plt.legend() 

    # function to show the plot 
    plt.show()

# %%
draw_cumulative_score_6(['a3c_play_score_card_100.csv', 'dqn_play_score_card_100.csv', 'random_score_card_100.csv'], 
                        ['A3C Agent', 'DQN Agent', 'Random Agent'])

# %%
a3c_play = [
("Ticks", 1, "Action", 1, "Ob", [ 1. ,  10. ,   5.06], "R", 0, "Total Reward", 0),
("Ticks", 2, "Action", 0, "Ob", ['0' ,'9.74', '7.45'], "R", 3, "Total Reward", 3),
("Ticks", 3, "Action", 1, "Ob", [ 1. ,  10. ,   6.29], "R", 0, "Total Reward", 3),
("Ticks", 4, "Action", 0, "Ob", ['0' ,'7.42', '5.36'], "R", 3, "Total Reward", 6),
("Ticks", 5, "Action", 1, "Ob", [ 1. ,  10. ,   3.84], "R", 0, "Total Reward", 6),
("Ticks", 6, "Action", 0, "Ob", ['0' ,'7.49' '5.43'], "R", 3, "Total Reward", 9),
("Ticks", 7, "Action", 1, "Ob", [ 1. ,  10. ,   7.02], "R", 0, "Total Reward", 9),
("Ticks", 8, "Action", 0, "Ob", ['0' ,'8.97' '6.92'], "R", 3, "Total Reward", 12),
("Ticks", 9, "Action", 1, "Ob", [ 1. ,  10. ,   6.28], "R", 0, "Total Reward", 12),
("Ticks", 10, "Action", 0, "Ob", ['0' ,'8.46' '6.46'], "R", 3, "Total Reward", 15),
("Ticks", 11, "Action", 1, "Ob", [ 1. ,  10. ,   4.92], "R", 0, "Total Reward", 15),
("Ticks", 12, "Action", 0, "Ob", ['0' ,'8.84' '6.73'], "R", 3, "Total Reward", 18),
("Ticks", 13, "Action", 1, "Ob", [ 1. ,  10. ,   6.86], "R", 0, "Total Reward", 18),
("Ticks", 14, "Action", 0, "Ob", ['0' ,'11.7' ,'0.0'], "R", 3, "Total Reward", 21),
("Ticks", 15, "Action", 0, "Ob", ['0' ,'10.2', '7.91'], "R", 3, "Total Reward", 24),
("Ticks", 16, "Action", 1, "Ob", [ 1. ,  10. ,   6.87], "R", 0, "Total Reward", 24),
("Ticks", 17, "Action", 0, "Ob", ['0' ,'6.11' ,'4.17'], "R", 3, "Total Reward", 27),
("Ticks", 18, "Action", 1, "Ob", [ 1. ,  10. ,   7.18], "R", 0, "Total Reward", 27),
("Ticks", 19, "Action", 0, "Ob", ['0' ,'7.83' '5.71'], "R", 3, "Total Reward", 30),
("Ticks", 20, "Action", 1, "Ob", [ 1. ,  10. ,   6.23], "R", 0, "Total Reward", 30),
("Ticks", 21, "Action", 0, "Ob", ['0' ,'9.67', '7.63'], "R", 3, "Total Reward", 33),
("Ticks", 22, "Action", 1, "Ob", [ 1. ,  10. ,   5.33], "R", 0, "Total Reward", 33),
("Ticks", 23, "Action", 0, "Ob", ['0' ,'8.89', '6.65'], "R", 3, "Total Reward", 36),
("Ticks", 24, "Action", 1, "Ob", [ 1. ,  10. ,   6.02], "R", 0, "Total Reward", 36),
("Ticks", 25, "Action", 0, "Ob", ['0' ,'4.88', '2.8099999999999996'], "R", -1, "Total Reward", 35),
("Ticks", 26, "Action", 1, "Ob", [ 1. ,  10. ,   4.76], "R", 0, "Total Reward", 35),
("Ticks", 27, "Action", 0, "Ob", ['0' ,'5.49', '3.37'], "R", -1, "Total Reward", 34),
("Ticks", 28, "Action", 1, "Ob", [ 1. ,  10. ,   1.95], "R", 0, "Total Reward", 34),
("Ticks", 29, "Action", 0, "Ob", ['0' ,'4.90', '2.75'], "R", -1, "Total Reward", 33),
("Ticks", 30, "Action", 0, "Ob", ['0' ,'7.30', '5.26'], "R", 3, "Total Reward", 36)
]

# %%
DeepRoute_DQN_Algorithm = [
    ('Ticks',  1 , 'Action',  0 , 'Ob',  (0, '8.66', 6.5600000000000005) , 'R',  3 , 'Total Reward',  3),                                    
    ('Ticks',  2 , 'Action',  0 , 'Ob',  (0, '8.74', 6.63) , 'R',  3 , 'Total Reward',  6),                                   
    ('Ticks',  3 , 'Action',  0 , 'Ob',  (0, '8.52', 6.3) , 'R',  3 , 'Total Reward',  9),                                 
    ('Ticks',  4 , 'Action',  0 , 'Ob',  (0, '11.2', 8.83) , 'R',  3 , 'Total Reward',  12),                                     
    ('Ticks',  5 , 'Action',  0 , 'Ob',  (0, '6.92', 4.9) , 'R',  3 , 'Total Reward',  15),                                 
    ('Ticks',  6 , 'Action',  0 , 'Ob',  (0, '4.09', 2.26) , 'R',  -1 , 'Total Reward',  14),                                    
    ('Ticks',  7 , 'Action',  1 , 'Ob',  (1, 10.0, 6.0600000000000005) , 'R',  0 , 'Total Reward',  14),                                                
    ('Ticks',  8 , 'Action',  0 , 'Ob',  (0, '7.88', 5.77) , 'R',  3 , 'Total Reward',  17),                                   
    ('Ticks',  9 , 'Action',  0 , 'Ob',  (0, '7.27', 5.24) , 'R',  3 , 'Total Reward',  20),                                     
    ('Ticks',  10 , 'Action',  0 , 'Ob',  (0, '8.03', 6.04) , 'R',  3 , 'Total Reward',  23),                                                
    ('Ticks',  11 , 'Action',  0 , 'Ob',  (0, '5.66', 3.67) , 'R',  -1 , 'Total Reward',  22),                                                   
    ('Ticks',  12 , 'Action',  1 , 'Ob',  (1, 10.0, 8.83) , 'R',  0 , 'Total Reward',  22 ),                                               
    ('Ticks',  13 , 'Action',  0 , 'Ob',  (0, '5.98', 3.75) , 'R',  -1 , 'Total Reward',  21  ),                                  
    ('Ticks',  14 , 'Action',  1 , 'Ob',  (1, 10.0, 2.92) , 'R',  0 , 'Total Reward',  21  ),                                 
    ('Ticks',  15 , 'Action',  0 , 'Ob',  (0, '8.32', 6.29) , 'R',  3 , 'Total Reward',  24 ),                                  
    ('Ticks',  16 , 'Action',  0 , 'Ob',  (0, '6.74', 4.79) , 'R',  3 , 'Total Reward',  27   ),                                
    ('Ticks',  17 , 'Action',  0 , 'Ob',  (0, '10.6', 8.46) , 'R',  3 , 'Total Reward',  30     ),    
    ('Ticks',  18 , 'Action',  0 , 'Ob',  (0, '7.24', 5.24) , 'R',  3 , 'Total Reward',  33    ),
    ('Ticks',  19 , 'Action',  0 , 'Ob',  (0, '4.34', 2.38) , 'R',  -1 , 'Total Reward',  32),
    ('Ticks',  20 , 'Action',  1 , 'Ob',  (1, 10.0, 4.81) , 'R',  0 , 'Total Reward',  32     ),                                                                                                
    ('Ticks',  21 , 'Action',  0 , 'Ob',  (0, '7.40', 5.28) , 'R',  3 , 'Total Reward',  35     ),                                                                                                            
    ('Ticks',  22 , 'Action',  0 , 'Ob',  (0, '10.3', 8.08) , 'R',  3 , 'Total Reward',  38      ),
    ('Ticks',  23 , 'Action',  0 , 'Ob',  (0, '12.4', 0.0) , 'R',  3 , 'Total Reward',  41         ),                                        
    ('Ticks',  24 , 'Action',  0 , 'Ob',  (0, '8.82', 6.71) , 'R',  3 , 'Total Reward',  44 ),                         
    ('Ticks',  25 , 'Action',  0 , 'Ob',  (0, '12.5', 0.0) , 'R',  3 , 'Total Reward',  47  ),                                
    ('Ticks',  26 , 'Action',  0 , 'Ob',  (0, '10.8', 8.52) , 'R',  3 , 'Total Reward',  50   ),                                 
    ('Ticks',  27 , 'Action',  0 , 'Ob',  (0, '8.83', 6.77) , 'R',  3 , 'Total Reward',  53     ),                              
    ('Ticks',  28 , 'Action',  0 , 'Ob',  (0, '8.06', 5.92) , 'R',  3 , 'Total Reward',  56       ),                              
    ('Ticks',  29 , 'Action',  0 , 'Ob',  (0, '7.25', 5.22) , 'R',  3 , 'Total Reward',  59         ),                                       
    ('Ticks',  30 , 'Action',  0 , 'Ob',  (0, '4.99', 2.7800000000000002) , 'R',  -1 , 'Total Reward',  58)
]

# %%
Ramdom_Algorithm = [
('Ticks:', 1, 'Action:', 0, 'Ob:', (0, '5.96', 5.09), 'R:', -4, 'Total Reward:', -4),
('Ticks:', 2, 'Action:', 1, 'Ob:', (1, 10.0, 3.3899999999999997), 'R:', -1, 'Total Reward:', -5),
('Ticks:', 3, 'Action:', 1, 'Ob:', (1, 10.0, 6.34), 'R:', -1, 'Total Reward:', -6),
('Ticks:', 4, 'Action:', 0, 'Ob:', (0, '5.08', 3.9299999999999997), 'R:', -4, 'Total Reward:', -10),
('Ticks:', 5, 'Action:', 1, 'Ob:', (1, 10.0, 4.73), 'R:', -1, 'Total Reward:', -11),
('Ticks:', 6, 'Action:', 1, 'Ob:', (1, 10.0, 5.34), 'R:', -1, 'Total Reward:', -12),
('Ticks:', 7, 'Action:', 1, 'Ob:', (1, 10.0, 8.05), 'R:', -1, 'Total Reward:', -13),
('Ticks:', 8, 'Action:', 1, 'Ob:', (1, 10.0, 6.2), 'R:', -1, 'Total Reward:', -14),
('Ticks:', 9, 'Action:', 1, 'Ob:', (1, 10.0, 5.27), 'R:', -1, 'Total Reward:', -15),
('Ticks:', 10, 'Action:', 1, 'Ob:', (1, 10.0, 6.77), 'R:', -1, 'Total Reward:', -16),
('Ticks:', 11, 'Action:', 1, 'Ob:', (1, 10.0, 4.89), 'R:', -1, 'Total Reward:', -17),
('Ticks:', 12, 'Action:', 0, 'Ob:', (0, '7.94', 7.029999999999999), 'R:', 2, 'Total Reward:', -15),
('Ticks:', 13, 'Action:', 0, 'Ob:', (0, '5.32', 4.11), 'R:', -4, 'Total Reward:', -19),
('Ticks:', 14, 'Action:', 1, 'Ob:', (1, 10.0, 4.4), 'R:', -1, 'Total Reward:', -20),
('Ticks:', 15, 'Action:', 0, 'Ob:', (0, '7.70', 6.02), 'R:', 2, 'Total Reward:', -18),
('Ticks:', 16, 'Action:', 0, 'Ob:', (0, '8.24', 6.92), 'R:', 2, 'Total Reward:', -16),
('Ticks:', 17, 'Action:', 0, 'Ob:', (0, '5.00', 4.11), 'R:', -4, 'Total Reward:', -20),
('Ticks:', 18, 'Action:', 0, 'Ob:', (0, '8.18', 6.720000000000001), 'R:', 2, 'Total Reward:', -18),
('Ticks:', 19, 'Action:', 0, 'Ob:', (0, '8.55', 8.15), 'R:', 2, 'Total Reward:', -16),
('Ticks:', 20, 'Action:', 1, 'Ob:', (1, 10.0, 2.41), 'R:', -1, 'Total Reward:', -17),
('Ticks:', 21, 'Action:', 0, 'Ob:', (0, '3.87', 3.83), 'R:', -4, 'Total Reward:', -21),
('Ticks:', 22, 'Action:', 1, 'Ob:', (1, 10.0, 6.33), 'R:', -1, 'Total Reward:', -22),
('Ticks:', 23, 'Action:', 1, 'Ob:', (1, 10.0, 7.57), 'R:', -1, 'Total Reward:', -23),
('Ticks:', 24, 'Action:', 0, 'Ob:', (0, '6.88', 5.42), 'R:', 2, 'Total Reward:', -21),
('Ticks:', 25, 'Action:', 0, 'Ob:', (0, '4.89', 4.53), 'R:', -4, 'Total Reward:', -25),
('Ticks:', 26, 'Action:', 1, 'Ob:', (1, 10.0, 4.27), 'R:', -1, 'Total Reward:', -26),
('Ticks:', 27, 'Action:', 1, 'Ob:', (1, 10.0, 2.95), 'R:', -1, 'Total Reward:', -27),
('Ticks:', 28, 'Action:', 1, 'Ob:', (1, 10.0, 6.49), 'R:', -1, 'Total Reward:', -28),
('Ticks:', 29, 'Action:', 1, 'Ob:', (1, 10.0, 5.69), 'R:', -1, 'Total Reward:', -29),
('Ticks:', 30, 'Action:', 0, 'Ob:', (0, '6.76', 5.34), 'R:', 2, 'Total Reward:', -27)
]

# %%
# x axis values 
x1 =  [float(x[1]) for x in deterministic_trial]
#print (x)
# corresponding y axis values 
y1 = [float(x[9]) for x in deterministic_trial]
#print (y)

# plotting the points  
#plt.plot(x, y) 
#plt.plot(x1, y1, label = "Deterministic Trial")  

y2 = [float(x[9]) for x in Ramdom_Algorithm]
plt.plot(x1, y2, label = "Ramdom_Algorithm")  

y3 = [float(x[9]) for x in DeepRoute_DQN_Algorithm]
plt.plot(x1, y3, label = "DeepRoute_DQN_Algorithm")  

#y4 = [float(x[9]) for x in a3c_play]
#plt.plot(x1, y4, label = "A3C Play")  

# naming the x axis 
plt.xlabel('No. of Runs') 
# naming the y axis 
#plt.ylabel('Link Throughput') 

# giving a title to my graph 
plt.title("Toal Cumulative Reward") 

# show a legend on the plot 
plt.legend() 

# function to show the plot 
plt.show()
