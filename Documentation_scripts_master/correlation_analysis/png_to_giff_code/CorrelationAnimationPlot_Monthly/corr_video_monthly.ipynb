# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import statsmodels.api as sm
import warnings
import itertools
from datetime import datetime
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["font.family"] = "sans-serif"
print('hello')
# Out:
# hello

# %%
df = pd.read_csv('2018_1hourdata.csv')

# %%
del df['Time']
#del df['Days']

# %%
#df=(df-df.mean())/df.std()

# %%
scaler = MinMaxScaler() 
scaled_values = scaler.fit_transform(df) 
df.loc[:,:] = scaled_values

# %%
df.shape
# Out:
# (8760, 96)

# %%
df.head()
# Out:
#    SACR_SUNN_in  SACR_SUNN_out  LOND_NEWY_in  LOND_NEWY_out  JGI_SACR_in  \
# 0      0.183318       0.117414      0.021212       0.148501     0.329815
# 1      0.174579       0.104370      0.023756       0.088611     0.000134
# 2      0.157498       0.087167      0.038367       0.209381     0.000131
# 3      0.145031       0.078593      0.020522       0.080683     0.329310
# 4      0.139044       0.090299      0.016532       0.033987     0.000093
#
#    JGI_SACR_out  HOUS_PANTEX_in  HOUS_PANTEX_out  BOIS_PNWG_in  BOIS_PNWG_out  \
# 0      0.493342        0.155905         0.063231      0.007080       0.084360
# 1      0.491478        0.135429         0.044909      0.004478       0.086059
# 2      0.265831        0.156445         0.028213      0.032509       0.087849
# 3      0.174619        0.128006         0.033498      0.003305       0.081368
# 4      0.118832        0.084286         0.051395      0.004747       0.081931
#
#    ...  AMST_LOND_in  AMST_LOND_out  FNAL_STAR_in  FNAL_STAR_out  \
# 0  ...      0.054124       0.183158      0.022430       0.058715
# 1  ...      0.075158       0.101939      0.070067       0.429809
# 2  ...      0.116311       0.207171      0.085395       0.322870
# 3  ...      0.068978       0.097016      0.009535       0.123338
# 4  ...      0.040821       0.060467      0.013638       0.100955
#
#    BOST_STAR_in  BOST_STAR_out  BOST_NEWY_in  BOST_NEWY_out  ATLA_WASH_in  \
# 0      0.078657       0.188405      0.186593       0.047319      0.116545
# 1      0.063583       0.137190      0.131654       0.044038      0.118011
# 2      0.092352       0.230291      0.262890       0.051411      0.126206
# 3      0.056347       0.089520      0.128496       0.039417      0.144168
# 4      0.038289       0.057177      0.080680       0.041211      0.145543
#
#    ATLA_WASH_out
# 0       0.158699
# 1       0.116589
# 2       0.091409
# 3       0.149968
# 4       0.130169
#
# [5 rows x 96 columns]

# %%
corr = df.corr().round(2)
plt.figure(figsize = (60,50))
sns.set(font_scale=2.0)
sns.heatmap(corr,cmap='coolwarm',annot=True, annot_kws={"size":10})
plt.title("One-year", fontsize=80)
plt.savefig('corr_oneyear.png')

# %%
df1 = df.loc[0:730, :]

# %%
df1.shape

# %%
df1 = df.loc[0:730, :]
corr1 = df1.corr().round(2)
plt.figure(figsize = (60,50))
sns.heatmap(corr1,cmap='coolwarm',annot=True, annot_kws={"size":10})
plt.title("January", fontsize=50)
plt.savefig('corr_jan.png')

# %%
df2 = df.loc[0:1460, :]

# %%
df2.shape

# %%
corr2 = df2.corr().round(2)
plt.figure(figsize = (60,50))
sns.heatmap(corr2,cmap='coolwarm',annot=True, annot_kws={"size":10})
plt.title("Febraury", fontsize=50)
plt.savefig('corr_feb.png')

# %%
df3 = df.loc[0:2190, :]

# %%
df3.shape

# %%
corr3 = df3.corr().round(2)
plt.figure(figsize = (60,50))
sns.heatmap(corr3,cmap='coolwarm',annot=True, annot_kws={"size":10})
plt.title("March", fontsize=50)
plt.savefig('corr_mar.png')

# %%
df4 = df.loc[0:2920, :]

# %%
corr4 = df4.corr().round(2)
plt.figure(figsize = (60,50))
sns.heatmap(corr4,cmap='coolwarm',annot=True, annot_kws={"size":10})
plt.title("April", fontsize=50)
plt.savefig('corr_apr.png')

# %%
df5 = df.loc[0:3650, :]

# %%
corr5 = df5.corr().round(2)
plt.figure(figsize = (60,50))
sns.heatmap(corr5,cmap='coolwarm',annot=True, annot_kws={"size":10})
plt.title("May", fontsize=50)
plt.savefig('corr_may.png')

# %%
df6 = df.loc[0:4380, :]

# %%
corr6 = df6.corr().round(2)
plt.figure(figsize = (60,50))
sns.heatmap(corr6,cmap='coolwarm',annot=True, annot_kws={"size":10})
plt.title("June", fontsize=50)
plt.savefig('corr_june.png')

# %%
df7 = df.loc[0:5110, :]

# %%
corr7 = df7.corr().round(2)
plt.figure(figsize = (60,50))
sns.heatmap(corr7,cmap='coolwarm',annot=True, annot_kws={"size":10})
plt.title("July", fontsize=50)
plt.savefig('corr_july.png')

# %%
df8 = df.loc[0:5840, :]

# %%
corr8 = df8.corr().round(2)
plt.figure(figsize = (60,50))
sns.heatmap(corr8,cmap='coolwarm',annot=True, annot_kws={"size":10})
plt.title("August", fontsize=50)
plt.savefig('corr_aug.png')

# %%
df9 = df.loc[0:6570, :]

# %%
corr9 = df9.corr().round(2)
plt.figure(figsize = (60,50))
sns.heatmap(corr9,cmap='coolwarm',annot=True, annot_kws={"size":10})
plt.title("September", fontsize=50)
plt.savefig('corr_sep.png')

# %%
df10 = df.loc[0:7300, :]

# %%
corr10 = df10.corr().round(2)
plt.figure(figsize = (60,50))
sns.heatmap(corr10,cmap='coolwarm',annot=True, annot_kws={"size":10})
plt.title("October", fontsize=50)
plt.savefig('corr_oct.png')

# %%
df11 = df.loc[0:8030, :]

# %%
df11.shape

# %%
corr11 = df11.corr().round(2)
plt.figure(figsize = (60,50))
sns.heatmap(corr11,cmap='coolwarm',annot=True, annot_kws={"size":10})
plt.title("November", fontsize=50)
plt.savefig('corr_nov.png')

# %%
df12 = df.loc[0:7300, :]

# %%
corr12 = df12.corr().round(2)
plt.figure(figsize = (60,50))
sns.heatmap(corr12,cmap='coolwarm',annot=True, annot_kws={"size":10})
plt.title("December", fontsize=50)
plt.savefig('corr_dec.png')
