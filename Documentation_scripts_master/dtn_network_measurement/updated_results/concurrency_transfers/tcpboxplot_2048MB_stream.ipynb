# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from pylab import *
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 40})
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
rc('axes', linewidth=4)

# %%
#pwd

# %%
df = pd.read_csv('tcpboxplot_2048MB.csv')

# %%
df.head(5)
# Out:
#     Aggregated Throughput(Gbps) Data Size Data Streams
# 0                      2.867651     100MB     1-Stream
# 1                      2.753898     100MB     1-Stream
# 2                      3.009840     100MB     1-Stream
# 3                      3.009840     100MB     1-Stream
# 4                      2.753898     100MB     1-Stream

# %%
fig = plt.gcf()

# Changing Seaborn Plot size
fig.set_size_inches(21, 13)

# Setting the font scale
sns.set(style="ticks",font_scale=3.5, rc={"lines.linewidth": 3})
sns.boxplot(x="Data Size", y=" Aggregated Throughput(Gbps)", hue="Data Streams",data=df, palette="colorblind")
rc('axes', linewidth=4)
plt.title('S = 2048MB')
plt.show()
