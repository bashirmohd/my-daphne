# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from pylab import *
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({'font.size': 40})
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
rc('axes', linewidth=4)
plt.rcParams["figure.figsize"] = (21, 15)

# %%
#ls

# %%
labels = ['128', '512', '1024', '2048', '3072']

iperf = [133, 216, 250, 441, 751]
preflight = [160.1509901, 300.5565323, 359.7394409, 580.4443962, 785.2579103]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, iperf, width, label='iperf')
rects2 = ax.bar(x + width/2, preflight, width, label='preflight')

# Add some text for labels, title and custom x-axis tick labels, etc.


ax.set_ylabel("Throughput (Mbps)")
ax.set_xlabel('Buffer Size (S) in (KB)')
ax.set_title('5MB')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
fig.tight_layout()
plt.show()

# %%
labels = ['128', '512', '1024', '2048', '3072']

iperf = [159.6, 259.2, 300, 532.8, 901.2]
preflight = [240.259, 360.661, 431.674, 696.524, 942.357]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, iperf, width, label='iperf')
rects2 = ax.bar(x + width/2, preflight, width, label='preflight')

# Add some text for labels, title and custom x-axis tick labels, etc.


ax.set_ylabel("Throughput (Mbps)")
ax.set_xlabel('Buffer Size (S) in (KB)')
ax.set_title('10MB')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
fig.tight_layout()
plt.show()

# %%
labels = ['128', '512', '1024', '2048', '3072']

iperf = [191.52, 388.8, 360, 639.36, 1082.52]
preflight = [288.350, 432.152, 517.287, 835.82, 1130.82]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, iperf, width, label='iperf')
rects2 = ax.bar(x + width/2, preflight, width, label='preflight')

# Add some text for labels, title and custom x-axis tick labels, etc.


ax.set_ylabel("Throughput (Mbps)")
ax.set_xlabel('Buffer Size (S) in (KB)')
ax.set_title('10MB')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
fig.tight_layout()
plt.show()

# %%
labels = ['128', '512', '1024', '2048', '3072']

iperf = [229.82, 466.58, 432.76, 767.23, 1299.02]
preflight = [346.502, 518.40, 620.744, 1002.98, 1356.98]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, iperf, width, label='iperf')
rects2 = ax.bar(x + width/2, preflight, width, label='preflight')

# Add some text for labels, title and custom x-axis tick labels, etc.


ax.set_ylabel("Throughput (Mbps)")
ax.set_xlabel('Buffer Size (S) in (KB)')
ax.set_title('20MB')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
fig.tight_layout()
plt.show()

# %%
labels = ['128', '512', '1024', '2048', '3072']

iperf = [435.65, 886.50, 822.24, 1457.73, 2468.13]
preflight = [658.35, 984.96, 1179.41, 1905.66, 2578.20]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, iperf, width, label='iperf')
rects2 = ax.bar(x + width/2, preflight, width, label='preflight')

# Add some text for labels, title and custom x-axis tick labels, etc.


ax.set_ylabel("Throughput (Mbps)")
ax.set_xlabel('Buffer Size (S) in (KB)')
ax.set_title('50MB')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
fig.tight_layout()
plt.show()

# %%
labels = ['128', '512', '1024', '2048', '3072']

iperf = [827.73, 1476.30 , 1562.25, 2703.88,3867.98 ]
preflight = [987.65, 1684.35, 1769.79, 2898.19,  4689.44 ]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, iperf, width, label='iperf')
rects2 = ax.bar(x + width/2, preflight, width, label='preflight')

# Add some text for labels, title and custom x-axis tick labels, etc.


ax.set_ylabel("Throughput (Mbps)")
ax.set_xlabel('Buffer Size (S) in (KB)')
ax.set_title('100MB')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
fig.tight_layout()
plt.show()

# %%
labels = ['8','16','64','128', '512', '1024', '2048']

iperf = [0.255, 0.413 , 1.250, 2.080, 1.950, 1.330, 1.200]
preflight = [0.378, 0.539, 1.374, 2.2036,  2.079, 1.453, 1.332 ]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, iperf, width, label='iperf')
rects2 = ax.bar(x + width/2, preflight, width, label='preflight')

# Add some text for labels, title and custom x-axis tick labels, etc.


ax.set_ylabel('Measured Throughput (Gbps)')
ax.set_xlabel('Window Size (KB)')
ax.set_title('')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
fig.tight_layout()
plt.show()
