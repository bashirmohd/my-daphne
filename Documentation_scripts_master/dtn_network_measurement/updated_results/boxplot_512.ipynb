# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from pylab import *
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 40})
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
rc('axes', linewidth=3)

# %%
pwd
# Out:
# '/Users/bashirm/Documents/largefiles'

# %%
df = pd.read_csv('box_plot_512.csv')

# %%
df.head()
# Out:
#      Tp_5mb   Tp_10mb   Tp_20mb   Tp_50mb  Tp_100mb
# 0  1.364878  0.819036  0.682553  0.585059  0.315053
# 1  1.023744  0.585059  0.819036  0.585059  0.315053
# 2  1.364878  0.819036  0.819036  0.682553  0.511936
# 3  1.364878  0.682553  0.819036  0.511936  0.341305
# 4  0.682553  0.819036  0.682553  0.682553  0.372330

# %%
fig = plt.gcf()

# Changing Seaborn Plot size
fig.set_size_inches(21, 13)

# Setting the font scale
sns.set(font_scale=4, style="white" )
sns.boxplot(data=df)
plt.xlabel('Data Transfer at BufferSize S = 512')
plt.ylabel('Throughput (Mbps)')
plt.show()
