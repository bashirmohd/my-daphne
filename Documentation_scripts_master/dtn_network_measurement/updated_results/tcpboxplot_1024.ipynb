# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from pylab import *
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 40})
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
rc('axes', linewidth=6)

# %%
df = pd.read_csv('tcpboxplot_1024.csv')

# %%
df.head(5)
# Out:
#    Throughput (Mbps) Data Transfer TCP Algorithm
# 0           0.662610        Tp_5mb          Reno
# 1           0.799118        Tp_5mb          Reno
# 2           1.003872        Tp_5mb          Reno
# 3           1.345106        Tp_5mb          Reno
# 4           1.150119        Tp_5mb          Reno

# %%
fig = plt.gcf()

# Changing Seaborn Plot size
fig.set_size_inches(21, 13)

# Setting the font scale
sns.set(style="ticks",font_scale=4, rc={"lines.linewidth": 3})
sns.boxplot(x="Data Transfer", y="Throughput (Mbps)", hue="TCP Algorithm",data=df, palette="colorblind")
plt.title('S = 1024KB')
plt.show()
