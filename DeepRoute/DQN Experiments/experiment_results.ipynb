# %%
import pandas
import matplotlib
import numpy as np
from pandas import Series
import matplotlib.pyplot as plt 

matplotlib.rcParams.update({'font.size': 12})

plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams['xtick.labelsize']=12
plt.rcParams['ytick.labelsize']=12

# %matplotlib inline

# %%
print('homeemm')
# Out:
# homeemm

# %%
Qlearning_experiment = [
('Ticks:', 1, 'Action:', 1, 'Ob:', (1, 10.0, 5.09), 'R:', -1, 'Total Reward:', -1),
('Ticks:', 2, 'Action:', 1, 'Ob:', (1, 10.0, 8.05), 'R:', -1, 'Total Reward:', -7),
('Ticks:', 3, 'Action:', 0, 'Ob:', (0, '7.76', 6.2), 'R:', 2, 'Total Reward:', -4),
('Ticks:', 4, 'Action:', 0, 'Ob:', (0, '6.36', 5.27), 'R:', 2, 'Total Reward:', -3),
('Ticks:', 5, 'Action:', 1, 'Ob:', (1, 10.0, 6.77), 'R:', -1, 'Total Reward:', -4),
('Ticks:', 6, 'Action:', 1, 'Ob:', (1, 10.0, 8.05), 'R:', -1, 'Total Reward:', -5),
('Ticks:', 7, 'Action:', 0, 'Ob:', (0, '7.76', 6.2), 'R:', 2, 'Total Reward:', -4),
('Ticks:', 8, 'Action:', 0, 'Ob:', (0, '6.36', 5.27), 'R:', 2, 'Total Reward:', -3),
('Ticks:', 9, 'Action:', 1, 'Ob:', (1, 10.0, 6.77), 'R:', -1, 'Total Reward:', -4),
('Ticks:', 10, 'Action:', 1, 'Ob:', (1, 10.0, 6.77), 'R:', -1, 'Total Reward:', -4),
('Ticks:', 11, 'Action:', 0, 'Ob:', (0, '5.92', 4.89), 'R:', -4, 'Total Reward:', -8),
('Ticks:', 12, 'Action:', 1, 'Ob:', (1, 10.0, 7.029999999999999), 'R:', -1, 'Total Reward:', -9),
('Ticks:', 13, 'Action:', 0, 'Ob:', (0, '4.80', 4.15), 'R:', -4, 'Total Reward:', -13),
('Ticks:', 14, 'Action:', 1, 'Ob:', (1, 10.0, 4.4), 'R:', -1, 'Total Reward:', -14),
('Ticks:', 15, 'Action:', 1, 'Ob:', (1, 10.0, 6.029999999999999), 'R:', -1, 'Total Reward:', -10),
('Ticks:', 16, 'Action:', 0, 'Ob:', (0, '7.21', 6.91), 'R:', 2, 'Total Reward:', -10),
('Ticks:', 17, 'Action:', 0, 'Ob:', (0, '4.68', 3.7800000000000002), 'R:', -4, 'Total Reward:', -12),
('Ticks:', 18, 'Action:', 1, 'Ob:', (1, 10.0, 6.720000000000001), 'R:', -1, 'Total Reward:', -5),
('Ticks:', 19, 'Action:', 0, 'Ob:', (0, '9.54', 8.15), 'R:', 2, 'Total Reward:', -12),
('Ticks:', 20, 'Action:', 0, 'Ob:', (0, '4.12', 3.51), 'R:', -4, 'Total Reward:', -16),
('Ticks:', 21, 'Action:', 1, 'Ob:', (1, 10.0, 2.5700000000000003), 'R:', -1, 'Total Reward:', -20),
('Ticks:', 22, 'Action:', 1, 'Ob:', (1, 10.0, 6.33), 'R:', -1, 'Total Reward:', -20),
('Ticks:', 23, 'Action:', 0, 'Ob:', (0, '8.97', 7.57), 'R:', 2, 'Total Reward:', -20),
('Ticks:', 24, 'Action:', 0, 'Ob:', (0, '6.57', 5.42), 'R:', 2, 'Total Reward:', -18),
('Ticks:', 25, 'Action:', 1, 'Ob:', (1, 10.0, 3.84), 'R:', -1, 'Total Reward:', -22),
('Ticks:', 26, 'Action:', 1, 'Ob:', (1, 10.0, 4.27), 'R:', -1, 'Total Reward:', -23),
('Ticks:', 27, 'Action:', 1, 'Ob:', (1, 10.0, 2.95), 'R:', -1, 'Total Reward:', -24),
('Ticks:', 28, 'Action:', 1, 'Ob:', (1, 10.0, 6.49), 'R:', -1, 'Total Reward:', -25),
('Ticks:', 29, 'Action:', 0, 'Ob:', (0, '6.90', 5.69), 'R:', 2, 'Total Reward:', -23),
('Ticks:', 30, 'Action:', 1, 'Ob:', (1, 10.0, 5.34), 'R:', -1, 'Total Reward:', -24),
('Ticks:', 31, 'Action:', 1, 'Ob:', (1, 10.0, 5.09), 'R:', -1, 'Total Reward:', -1),
('Ticks:', 32, 'Action:', 0, 'Ob:', (0, '4.94', 4.19), 'R:', -4, 'Total Reward:', -7),
('Ticks:', 33, 'Action:', 1, 'Ob:', (1, 10.0, 4.73), 'R:', -1, 'Total Reward:', -8),
('Ticks:', 34, 'Action:', 1, 'Ob:', (1, 10.0, 5.34), 'R:', -1, 'Total Reward:', -9),
('Ticks:', 35, 'Action:', 1, 'Ob:', (1, 10.0, 8.05), 'R:', -1, 'Total Reward:', -10),
('Ticks:', 36, 'Action:', 0, 'Ob:', (0, '7.76', 6.2), 'R:', 2, 'Total Reward:', -8),
('Ticks:', 37, 'Action:', 0, 'Ob:', (0, '6.36', 5.27), 'R:', 2, 'Total Reward:', -6),
('Ticks:', 38, 'Action:', 1, 'Ob:', (1, 10.0, 6.77), 'R:', -1, 'Total Reward:', -7),
('Ticks:', 39, 'Action:', 1, 'Ob:', (1, 10.0, 6.77), 'R:', -1, 'Total Reward:', -7),
('Ticks:', 40, 'Action:', 0, 'Ob:', (0, '5.92', 4.89), 'R:', -4, 'Total Reward:', -11),
('Ticks:', 41, 'Action:', 1, 'Ob:', (1, 10.0, 7.029999999999999), 'R:', -1, 'Total Reward:', -12),
('Ticks:', 42, 'Action:', 0, 'Ob:', (0, '4.80', 4.15), 'R:', -4, 'Total Reward:', -16),
('Ticks:', 43, 'Action:', 1, 'Ob:', (1, 10.0, 4.4), 'R:', -1, 'Total Reward:', -17),
('Ticks:', 44, 'Action:', 1, 'Ob:', (1, 10.0, 6.029999999999999), 'R:', -1, 'Total Reward:', -18),
('Ticks:', 45, 'Action:', 0, 'Ob:', (0, '7.21', 6.91), 'R:', 2, 'Total Reward:', -16),
('Ticks:', 46, 'Action:', 0, 'Ob:', (0, '4.68', 3.7800000000000002), 'R:', -4, 'Total Reward:', -20),
('Ticks:', 47, 'Action:', 1, 'Ob:', (1, 10.0, 6.720000000000001), 'R:', -1, 'Total Reward:', -21),
('Ticks:', 48, 'Action:', 0, 'Ob:', (0, '9.54', 8.15), 'R:', 2, 'Total Reward:', -19),
('Ticks:', 49, 'Action:', 0, 'Ob:', (0, '4.12', 3.51), 'R:', -4, 'Total Reward:', -23),
('Ticks:', 50, 'Action:', 1, 'Ob:', (1, 10.0, 5.34), 'R:', -1, 'Total Reward:', -24),
('Ticks:', 51, 'Action:', 1, 'Ob:', (1, 10.0, 5.09), 'R:', -1, 'Total Reward:', -1),
('Ticks:', 52, 'Action:', 1, 'Ob:', (1, 10.0, 6.34), 'R:', -1, 'Total Reward:', -3),
('Ticks:', 53, 'Action:', 0, 'Ob:', (0, '4.94', 4.19), 'R:', -4, 'Total Reward:', -7),
('Ticks:', 54, 'Action:', 1, 'Ob:', (1, 10.0, 4.73), 'R:', -1, 'Total Reward:', -8),
('Ticks:', 55, 'Action:', 1, 'Ob:', (1, 10.0, 5.34), 'R:', -1, 'Total Reward:', -9),
('Ticks:', 56, 'Action:', 1, 'Ob:', (1, 10.0, 8.05), 'R:', -1, 'Total Reward:', -10),
('Ticks:', 57, 'Action:', 0, 'Ob:', (0, '7.76', 6.2), 'R:', 2, 'Total Reward:', -8),
('Ticks:', 58, 'Action:', 0, 'Ob:', (0, '6.36', 5.27), 'R:', 2, 'Total Reward:', -6),
('Ticks:', 59, 'Action:', 1, 'Ob:', (1, 10.0, 6.77), 'R:', -1, 'Total Reward:', -7),
('Ticks:', 60, 'Action:', 1, 'Ob:', (1, 10.0, 6.77), 'R:', -1, 'Total Reward:', -7)
]

# %%
Random_experiment = [

('Ticks:', 1, 'Action:', 1, 'Ob:', (1, 10.0, 5.34), 'R:', -1, 'Total Reward:', -12),
('Ticks:', 2, 'Action:', 1, 'Ob:', (1, 10.0, 8.05), 'R:', -1, 'Total Reward:', -13),
('Ticks:', 3, 'Action:', 1, 'Ob:', (1, 9.0, 6.2), 'R:', -1, 'Total Reward:', -14),
('Ticks:', 4, 'Action:', 1, 'Ob:', (1, 9.0, 5.27), 'R:', -1, 'Total Reward:', -15),
('Ticks:', 5, 'Action:', 0, 'Ob:', (0, '5.96', 5.09), 'R:', -4, 'Total Reward:', -4),
('Ticks:', 6, 'Action:', 1, 'Ob:', (1, 9.0, 3.3899999999999997), 'R:', -1, 'Total Reward:', -5),
('Ticks:', 7, 'Action:', 1, 'Ob:', (1, 9.0, 6.34), 'R:', -1, 'Total Reward:', -6),
('Ticks:', 8, 'Action:', 0, 'Ob:', (0, '5.08', 3.9299999999999997), 'R:', -4, 'Total Reward:', -10),
('Ticks:', 9, 'Action:', 1, 'Ob:', (1, 9.0, 4.73), 'R:', -1, 'Total Reward:', -11),
('Ticks:', 10, 'Action:', 1, 'Ob:', (1, 9.0, 6.77), 'R:', -1, 'Total Reward:', -16),
('Ticks:', 11, 'Action:', 1, 'Ob:', (1, 9.0, 4.89), 'R:', -1, 'Total Reward:', -17),
('Ticks:', 12, 'Action:', 0, 'Ob:', (0, '7.94', 7.029999999999999), 'R:', 2, 'Total Reward:', -15),
('Ticks:', 13, 'Action:', 0, 'Ob:', (0, '5.32', 4.11), 'R:', -4, 'Total Reward:', -19),
('Ticks:', 14, 'Action:', 1, 'Ob:', (1, 9.0, 4.4), 'R:', -1, 'Total Reward:', -20),
('Ticks:', 15, 'Action:', 0, 'Ob:', (0, '7.70', 6.02), 'R:', 2, 'Total Reward:', -18),
('Ticks:', 16, 'Action:', 0, 'Ob:', (0, '8.24', 6.92), 'R:', 2, 'Total Reward:', -16),
('Ticks:', 17, 'Action:', 0, 'Ob:', (0, '5.00', 4.11), 'R:', -4, 'Total Reward:', -20),
('Ticks:', 18, 'Action:', 0, 'Ob:', (0, '8.18', 6.720000000000001), 'R:', 2, 'Total Reward:', -18),
('Ticks:', 19, 'Action:', 0, 'Ob:', (0, '8.55', 8.15), 'R:', 2, 'Total Reward:', -16),
('Ticks:', 20, 'Action:', 1, 'Ob:', (1, 9.0, 2.41), 'R:', -1, 'Total Reward:', -17),
('Ticks:', 21, 'Action:', 0, 'Ob:', (0, '3.87', 3.83), 'R:', -4, 'Total Reward:', -21),
('Ticks:', 22, 'Action:', 1, 'Ob:', (1, 9.0, 6.33), 'R:', -1, 'Total Reward:', -22),
('Ticks:', 23, 'Action:', 1, 'Ob:', (1, 9.0, 7.57), 'R:', -1, 'Total Reward:', -23),
('Ticks:', 24, 'Action:', 0, 'Ob:', (0, '6.88', 5.42), 'R:', 2, 'Total Reward:', -21),
('Ticks:', 25, 'Action:', 0, 'Ob:', (0, '4.89', 4.53), 'R:', -4, 'Total Reward:', -25),
('Ticks:', 26, 'Action:', 1, 'Ob:', (1, 9.0, 4.27), 'R:', -1, 'Total Reward:', -26),
('Ticks:', 27, 'Action:', 1, 'Ob:', (1, 9.0, 2.95), 'R:', -1, 'Total Reward:', -27),
('Ticks:', 28, 'Action:', 1, 'Ob:', (1, 9.0, 6.49), 'R:', -1, 'Total Reward:', -28),
('Ticks:', 29, 'Action:', 1, 'Ob:', (1, 9.0, 5.69), 'R:', -1, 'Total Reward:', -29),
('Ticks:', 30, 'Action:', 0, 'Ob:', (0, '6.76', 5.34), 'R:', 2, 'Total Reward:', -27),
('Ticks:', 31, 'Action:', 0, 'Ob:', (0, '8.55', 8.15), 'R:', 2, 'Total Reward:', -16),
('Ticks:', 32, 'Action:', 1, 'Ob:', (1, 10.0, 2.41), 'R:', -1, 'Total Reward:', -17),
('Ticks:', 33, 'Action:', 0, 'Ob:', (0, '3.87', 3.83), 'R:', -4, 'Total Reward:', -21),
('Ticks:', 34, 'Action:', 1, 'Ob:', (1, 9.0, 6.33), 'R:', -1, 'Total Reward:', -22),
('Ticks:', 35, 'Action:', 1, 'Ob:', (1, 9.0, 7.57), 'R:', -1, 'Total Reward:', -23),
('Ticks:', 36, 'Action:', 0, 'Ob:', (0, '6.88', 5.42), 'R:', 2, 'Total Reward:', -21),
('Ticks:', 37, 'Action:', 0, 'Ob:', (0, '4.89', 4.53), 'R:', -4, 'Total Reward:', -25),
('Ticks:', 38, 'Action:', 1, 'Ob:', (1, 9.0, 4.27), 'R:', -1, 'Total Reward:', -26),
('Ticks:', 39, 'Action:', 1, 'Ob:', (1, 9.0, 2.95), 'R:', -1, 'Total Reward:', -27),
('Ticks:', 40, 'Action:', 1, 'Ob:', (1, 9.0, 6.49), 'R:', -1, 'Total Reward:', -28),
('Ticks:', 41, 'Action:', 0, 'Ob:', (0, '8.55', 8.15), 'R:', 2, 'Total Reward:', -16),
('Ticks:', 42, 'Action:', 1, 'Ob:', (1, 8.0, 2.41), 'R:', -1, 'Total Reward:', -17),
('Ticks:', 43, 'Action:', 0, 'Ob:', (0, '3.87', 3.83), 'R:', -4, 'Total Reward:', -21),
('Ticks:', 44, 'Action:', 1, 'Ob:', (1, 9.0, 6.33), 'R:', -1, 'Total Reward:', -22),
('Ticks:', 45, 'Action:', 1, 'Ob:', (1, 9.0, 7.57), 'R:', -1, 'Total Reward:', -23),
('Ticks:', 46, 'Action:', 0, 'Ob:', (0, '6.88', 5.42), 'R:', 2, 'Total Reward:', -21),
('Ticks:', 47, 'Action:', 0, 'Ob:', (0, '4.89', 4.53), 'R:', -4, 'Total Reward:', -25),
('Ticks:', 48, 'Action:', 1, 'Ob:', (1, 7.0, 4.27), 'R:', -1, 'Total Reward:', -26),
('Ticks:', 49, 'Action:', 1, 'Ob:', (1, 8.0, 2.95), 'R:', -1, 'Total Reward:', -27),
('Ticks:', 50, 'Action:', 1, 'Ob:', (1, 9.0, 6.49), 'R:', -1, 'Total Reward:', -28),
('Ticks:', 51, 'Action:', 0, 'Ob:', (0, '8.55', 8.15), 'R:', 2, 'Total Reward:', -16),
('Ticks:', 52, 'Action:', 1, 'Ob:', (1, 8.0, 2.41), 'R:', -1, 'Total Reward:', -17),
('Ticks:', 53, 'Action:', 0, 'Ob:', (0, '3.87', 3.83), 'R:', -4, 'Total Reward:', -21),
('Ticks:', 54, 'Action:', 1, 'Ob:', (1, 9.0, 6.33), 'R:', -1, 'Total Reward:', -22),
('Ticks:', 55, 'Action:', 1, 'Ob:', (1, 9.0, 7.57), 'R:', -1, 'Total Reward:', -23),
('Ticks:', 56, 'Action:', 0, 'Ob:', (0, '6.88', 5.42), 'R:', 2, 'Total Reward:', -21),
('Ticks:', 57, 'Action:', 0, 'Ob:', (0, '4.89', 4.53), 'R:', -4, 'Total Reward:', -25),
('Ticks:', 58, 'Action:', 1, 'Ob:', (1, 7.0, 4.27), 'R:', -1, 'Total Reward:', -26),
('Ticks:', 59, 'Action:', 1, 'Ob:', (1, 8.0, 2.95), 'R:', -1, 'Total Reward:', -27),
('Ticks:', 60, 'Action:', 1, 'Ob:', (1, 9.0, 6.49), 'R:', -1, 'Total Reward:', -28)
]

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

def draw_graph(data, title):
    # x axis values 
    x1 =  [float(x[1]) for x in data]
    #print (x)
    # corresponding y axis values 
    y1 = [float(x[5][1]) for x in data]
    #print (y)

    # plotting the points  
    #plt.plot(x, y) 
    plt.plot(x1, y1,'k', label = "Actual Bandwidth on Links (Gbps)")  

    y2 = [float(x[5][2]) for x in data]
    plt.plot(x1, y2,'g-', label = "Bandwidth avial. on Internet2 link (Gbps)")  
    
    y3 = [float(x[7]) for x in data]

    plt.plot(x1, y3,'b-.', label = "Reward")
    
    y4 = [6.0 for x in data]

    plt.plot(x1, y4,'r--', label = "Threshold based on SLA(Gpbs)")


    # naming the x axis 
    plt.xlabel('No. of Runs') 
    # naming the y axis 
    #plt.ylabel('Link Throughput') 

    # giving a title to my graph 
    plt.title(title) 

    # show a legend on the plot 
    plt.legend(loc=9, bbox_to_anchor=(1.43, 0.3))

    
    
    plt.figure(figsize=(12,8))

    matplotlib.rcParams.update({'font.size':12})
    plt.rcParams["font.weight"] = "bold"
    plt.rcParams["axes.labelweight"] = "bold"
    #plt.rcParams.update({'font.size': 2})
    plt.rcParams['xtick.labelsize']=12
    plt.rcParams['ytick.labelsize']=12

    # function to show the plot 
    plt.show()

# %%
draw_graph(Qlearning_experiment, 'Qlearning Experiment')

# %%
plt.savefig('foo.png')

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

def draw_graph(data, title):
    # x axis values 
    x1 =  [float(x[1]) for x in data]
    #print (x)
    # corresponding y axis values 
    y1 = [float(x[5][1]) for x in data]
    #print (y)

    # plotting the points  
    #plt.plot(x, y) 
    plt.plot(x1, y1,'k', label = "Actual Bandwidth on Links (Gbps)")  

    y2 = [float(x[5][2]) for x in data]
    plt.plot(x1, y2,'g-', label = "Bandwidth avial. on Internet2 link (Gbps)")  
    
    y3 = [float(x[7]) for x in data]

    plt.plot(x1, y3,'b-.', label = "Reward")
    
    y4 = [6.0 for x in data]

    plt.plot(x1, y4,'r--', label = "Threshold based on SLA(Gpbs)")


    # naming the x axis 
    plt.xlabel('No. of Runs') 
    # naming the y axis 
    #plt.ylabel('Link Throughput') 

    # giving a title to my graph 
    plt.title(title) 

    # show a legend on the plot 
    plt.legend(loc=9, bbox_to_anchor=(1.43, 0.3))

    
    
    plt.figure(figsize=(12,8))

    matplotlib.rcParams.update({'font.size':12})
    plt.rcParams["font.weight"] = "bold"
    plt.rcParams["axes.labelweight"] = "bold"
    #plt.rcParams.update({'font.size': 2})
    plt.rcParams['xtick.labelsize']=12
    plt.rcParams['ytick.labelsize']=12

    # function to show the plot 
    plt.show()

# %%
draw_graph(Random_experiment, 'Random_experiment')

# %%
# x axis values 
x1 =  [float(x[1]) for x in Qlearning_experiment]
#print (x)
# corresponding y axis values 
y1 = [float(x[9]) for x in Qlearning_experiment]
#print (y)

# plotting the points  
#plt.plot(x, y) 
plt.plot(x1, y1, label = "Qlearning Experiment")  

y2 = [float(x[9]) for x in Random_experiment]
plt.plot(x1, y2, label = "Random_experiment")  


# naming the x axis 
plt.xlabel('No. of Runs') 
# naming the y axis 
#plt.ylabel('Link Throughput') 

# giving a title to my graph 
plt.title("Total Reward") 

# show a legend on the plot 
plt.legend(loc=9, bbox_to_anchor=(1.3, 0.25))


# function to show the plot 
plt.show()

# %%
def draw_cumulative_score(filename,title):
    df = pandas.read_csv(filename, header=None)
    data = df.values
    # x axis values 
    x =  [float(x[0]) for x in data]
    #print (x)
    # corresponding y axis values 
    y = [float(x[1]) for x in data]
    #print (y)
    series = Series(y)
    print ('Min', series.min(), 'Max', series.max(), 'mean', series.mean())
    # plotting the points  
    plt.plot(x, y) 

    # naming the x axis 
    plt.xlabel('No. of Episodes') 
    # naming the y axis 
    plt.ylabel('Total Score per episode') 

    # giving a title to my graph 
    plt.title(title) 

    # show a legend on the plot 
    # plt.legend() 

    # function to show the plot 
    plt.show() 
draw_cumulative_score('dqn_score_card.csv', 'DQN Agent')
# Out:
# Min -8.0 Max 168.0 mean 11.58

# %%
def draw_cumulative_score_4(filename,title):
    df = pandas.read_csv(filename, header=None)
    data = df.values[0:18]
    # x axis values 
    x =  [float(x[0]) for x in data]
    y = [float(x[1]) for x in data]
    # Tail-rolling average transform
    series = Series(y)
    rolling = series.rolling(window=3)
    rolling_mean = rolling.mean()
    print ('Min', series.min(), 'Max', series.max(), 'mean', series.mean())
    #print(rolling_mean.head(10))
    # plot original and transformed dataset
    #series.plot()
    plt.plot(x, rolling_mean, color='red') 
    plt.title(title) 
     # naming the x axis 
    plt.xlabel('No. of Episodes') 
    # naming the y axis 
    plt.ylabel('Total Score per timestep') 
    #rolling_mean.plot(color='red')
    plt.show()

# %%
draw_cumulative_score_4('dqn_score_card.csv', 'Rolling Mean of score')
# Out:
# Min -8.0 Max 168.0 mean 53.0

# %%
def draw_cumulative_score_4(filename,title):
    df = pandas.read_csv(filename, header=None)
    data = df.values[20:36]
    # x axis values 
    x =  [float(x[0]) for x in data]
    y = [float(x[1]) for x in data]
    # Tail-rolling average transform
    series = Series(y)
    rolling = series.rolling(window=3)
    rolling_mean = rolling.mean()
    print ('Min', series.min(), 'Max', series.max(), 'mean', series.mean())
    #print(rolling_mean.head(10))
    # plot original and transformed dataset
    #series.plot()
    plt.plot(x, rolling_mean, color='red') 
    plt.title(title) 
     # naming the x axis 
    plt.xlabel('No. of Episodes') 
    # naming the y axis 
    plt.ylabel('Total Score per timestep') 
    #rolling_mean.plot(color='red')
    plt.show()

# %%
draw_cumulative_score_4('dqn_score_card.csv', 'Rolling Mean of score')
# Out:
# Min -1.0 Max 12.0 mean 3.625

# %%
def draw_cumulative_score_4(filename,title):
    df = pandas.read_csv(filename, header=None)
    data = df.values[40:54]
    # x axis values 
    x =  [float(x[0]) for x in data]
    y = [float(x[1]) for x in data]
    # Tail-rolling average transform
    series = Series(y)
    rolling = series.rolling(window=3)
    rolling_mean = rolling.mean()
    print ('Min', series.min(), 'Max', series.max(), 'mean', series.mean())
    #print(rolling_mean.head(10))
    # plot original and transformed dataset
    #series.plot()
    plt.plot(x, rolling_mean, color='red') 
    plt.title(title) 
     # naming the x axis 
    plt.xlabel('No. of Episodes') 
    # naming the y axis 
    plt.ylabel('Total Score per timestep') 
    #rolling_mean.plot(color='red')
    plt.show()

# %%
draw_cumulative_score_4('dqn_score_card.csv', 'Rolling Mean of score')
# Out:
# Min -6.0 Max 12.0 mean 1.5

# %%
def draw_cumulative_score_4(filename,title):
    df = pandas.read_csv(filename, header=None)
    data = df.values[40:54]
    # x axis values 
    x =  [float(x[0]) for x in data]
    y = [float(x[1]) for x in data]
    # Tail-rolling average transform
    series = Series(y)
    rolling = series.rolling(window=3)
    rolling_mean = rolling.mean()
    print ('Min', series.min(), 'Max', series.max(), 'mean', series.mean())
    #print(rolling_mean.head(10))
    # plot original and transformed dataset
    #series.plot()
    plt.plot(x, rolling_mean, color='red') 
    plt.title(title) 
     # naming the x axis 
    plt.xlabel('No. of Episodes') 
    # naming the y axis 
    plt.ylabel('Total Score per timestep') 
    #rolling_mean.plot(color='red')
    plt.show()

# %%
draw_cumulative_score_4('dqn_score_card.csv', 'Rolling Mean of score')

# %%
def draw_cumulative_score_4(filename,title):
    df = pandas.read_csv(filename, header=None)
    data = df.values[60:100]
    # x axis values 
    x =  [float(x[0]) for x in data]
    y = [float(x[1]) for x in data]
    # Tail-rolling average transform
    series = Series(y)
    rolling = series.rolling(window=3)
    rolling_mean = rolling.mean()
    print ('Min', series.min(), 'Max', series.max(), 'mean', series.mean())
    #print(rolling_mean.head(10))
    # plot original and transformed dataset
    #series.plot()
    plt.plot(x, rolling_mean, color='red') 
    plt.title(title) 
     # naming the x axis 
    plt.xlabel('No. of Episodes') 
    # naming the y axis 
    plt.ylabel('Total Score per timestep') 
    #rolling_mean.plot(color='red')
    plt.show()

# %%
draw_cumulative_score_4('dqn_score_card.csv', 'Rolling Mean of score')
# Out:
# Min -6.0 Max 39.0 mean 1.05

# %%
DeepQN = [
    ('Ticks',  1 , 'Action',  0 , 'Ob',  (0, '8.66', 6.5600000000000005) , 'R',  3 , 'Total Reward',  3),                                    
    ('Ticks',  2 , 'Action',  0 , 'Ob',  (0, '8.74', 6.63) , 'R',  3 , 'Total Reward',  6),                                   
    ('Ticks',  3 , 'Action',  0 , 'Ob',  (0, '8.52', 6.3) , 'R',  3 , 'Total Reward',  9),                                 
    ('Ticks',  4 , 'Action',  0 , 'Ob',  (0, '11.2', 8.83) , 'R',  3 , 'Total Reward',  12),                                     
    ('Ticks',  5 , 'Action',  0 , 'Ob',  (0, '6.92', 4.9) , 'R',  3 , 'Total Reward',  15),                                 
    ('Ticks',  6 , 'Action',  0 , 'Ob',  (0, '4.09', 2.26) , 'R',  -1 , 'Total Reward',  14),                                    
    ('Ticks',  7 , 'Action',  1 , 'Ob',  (1, 10.0, 6.0600000000000005) , 'R',  0 , 'Total Reward',  14),                                                
    ('Ticks',  8 , 'Action',  0 , 'Ob',  (0, '7.88', 5.77) , 'R',  3 , 'Total Reward',  17),                                   
    ('Ticks',  9 , 'Action',  0 , 'Ob',  (0, '7.27', 5.24) , 'R',  3 , 'Total Reward',  20),                                     
    ('Ticks',  10 , 'Action',  0 , 'Ob',  (0, '8.03', 6.04) , 'R',  3 , 'Total Reward',  23),                                                
    ('Ticks',  11 , 'Action',  0 , 'Ob',  (0, '5.66', 3.67) , 'R',  -1 , 'Total Reward',  22),                                                   
    ('Ticks',  12 , 'Action',  1 , 'Ob',  (1, 10.0, 8.83) , 'R',  0 , 'Total Reward',  22 ),                                               
    ('Ticks',  13 , 'Action',  0 , 'Ob',  (0, '5.98', 3.75) , 'R',  -1 , 'Total Reward',  21  ),                                  
    ('Ticks',  14 , 'Action',  1 , 'Ob',  (1, 10.0, 2.92) , 'R',  0 , 'Total Reward',  21  ),                                 
    ('Ticks',  15 , 'Action',  0 , 'Ob',  (0, '8.32', 6.29) , 'R',  3 , 'Total Reward',  24 ),                                  
    ('Ticks',  16 , 'Action',  0 , 'Ob',  (0, '6.74', 4.79) , 'R',  3 , 'Total Reward',  27   ),                                
    ('Ticks',  17 , 'Action',  0 , 'Ob',  (0, '10.6', 8.46) , 'R',  3 , 'Total Reward',  30     ),    
    ('Ticks',  18 , 'Action',  0 , 'Ob',  (0, '7.24', 5.24) , 'R',  3 , 'Total Reward',  33    ),
    ('Ticks',  19 , 'Action',  0 , 'Ob',  (0, '4.34', 2.38) , 'R',  -1 , 'Total Reward',  32),
    ('Ticks',  20 , 'Action',  1 , 'Ob',  (1, 10.0, 4.81) , 'R',  0 , 'Total Reward',  32     ),                                                                                                
    ('Ticks',  21 , 'Action',  0 , 'Ob',  (0, '7.40', 5.28) , 'R',  3 , 'Total Reward',  35     ),                                                                                                            
    ('Ticks',  22 , 'Action',  0 , 'Ob',  (0, '10.3', 8.08) , 'R',  3 , 'Total Reward',  38      ),
    ('Ticks',  23 , 'Action',  0 , 'Ob',  (0, '12.4', 0.0) , 'R',  3 , 'Total Reward',  41         ),                                        
    ('Ticks',  24 , 'Action',  0 , 'Ob',  (0, '8.82', 6.71) , 'R',  3 , 'Total Reward',  44 ),                         
    ('Ticks',  25 , 'Action',  0 , 'Ob',  (0, '12.5', 0.0) , 'R',  3 , 'Total Reward',  47  ),                                
    ('Ticks',  26 , 'Action',  0 , 'Ob',  (0, '10.8', 8.52) , 'R',  3 , 'Total Reward',  50   ),                                 
    ('Ticks',  27 , 'Action',  0 , 'Ob',  (0, '8.83', 6.77) , 'R',  3 , 'Total Reward',  53     ),                              
    ('Ticks',  28 , 'Action',  0 , 'Ob',  (0, '8.06', 5.92) , 'R',  3 , 'Total Reward',  56       ),                              
    ('Ticks',  29 , 'Action',  0 , 'Ob',  (0, '7.25', 5.22) , 'R',  3 , 'Total Reward',  59         ),                                       
    ('Ticks',  30 , 'Action',  0 , 'Ob',  (0, '4.99', 2.7800000000000002) , 'R',  -1 , 'Total Reward',  58),
    ('Ticks',  31 , 'Action',  1 , 'Ob',  (1, 10.0, 4.81) , 'R',  0 , 'Total Reward',  32     ),                                                                                                
    ('Ticks',  32 , 'Action',  0 , 'Ob',  (0, '7.40', 5.28) , 'R',  3 , 'Total Reward',  35     ),                                                                                                            
    ('Ticks',  33 , 'Action',  0 , 'Ob',  (0, '12.4', 0.0) , 'R',  3 , 'Total Reward',  41         ),                                        
    ('Ticks',  34 , 'Action',  0 , 'Ob',  (0, '8.82', 6.71) , 'R',  3 , 'Total Reward',  44 ),                         
    ('Ticks',  35 , 'Action',  0 , 'Ob',  (0, '12.5', 0.0) , 'R',  3 , 'Total Reward',  47  ),                                
    ('Ticks',  36 , 'Action',  0 , 'Ob',  (0, '10.8', 8.52) , 'R',  3 , 'Total Reward',  50   ),                                 
    ('Ticks',  37 , 'Action',  0 , 'Ob',  (0, '8.83', 6.77) , 'R',  3 , 'Total Reward',  53     ),                              
    ('Ticks',  38 , 'Action',  0 , 'Ob',  (0, '8.06', 5.92) , 'R',  3 , 'Total Reward',  56       ),                              
    ('Ticks',  39 , 'Action',  0 , 'Ob',  (0, '7.25', 5.22) , 'R',  3 , 'Total Reward',  59         ), 
    ('Ticks',  40 , 'Action',  0 , 'Ob',  (0, '7.25', 5.22) , 'R',  3 , 'Total Reward',  59         ),
    ('Ticks',  41 , 'Action',  0 , 'Ob',  (0, '4.99', 2.7800000000000002) , 'R',  -1 , 'Total Reward',  58),
    ('Ticks',  42 , 'Action',  1 , 'Ob',  (1, 10.0, 4.81) , 'R',  0 , 'Total Reward',  32     ),                                                                                                
    ('Ticks',  43 , 'Action',  0 , 'Ob',  (0, '7.40', 5.28) , 'R',  3 , 'Total Reward',  35     ),                                                                                                            
    ('Ticks',  44 , 'Action',  0 , 'Ob',  (0, '10.3', 8.08) , 'R',  3 , 'Total Reward',  38      ),
    ('Ticks',  45 , 'Action',  0 , 'Ob',  (0, '12.4', 0.0) , 'R',  3 , 'Total Reward',  41         ),                                        
    ('Ticks',  46 , 'Action',  0 , 'Ob',  (0, '8.82', 6.71) , 'R',  3 , 'Total Reward',  44 ),                         
    ('Ticks',  47 , 'Action',  0 , 'Ob',  (0, '12.5', 0.0) , 'R',  3 , 'Total Reward',  47  ),                                
    ('Ticks',  48 , 'Action',  0 , 'Ob',  (0, '10.8', 8.52) , 'R',  3 , 'Total Reward',  50   ),                                 
    ('Ticks',  49 , 'Action',  0 , 'Ob',  (0, '8.83', 6.77) , 'R',  3 , 'Total Reward',  53     ),                              
    ('Ticks',  50 , 'Action',  0 , 'Ob',  (0, '8.06', 5.92) , 'R',  3 , 'Total Reward',  56       ),                              
    ('Ticks',  51 , 'Action',  0 , 'Ob',  (0, '7.25', 5.22) , 'R',  3 , 'Total Reward',  59         ),                                       
    ('Ticks',  52 , 'Action',  0 , 'Ob',  (0, '4.99', 2.7800000000000002) , 'R',  -1 , 'Total Reward',  58),
    ('Ticks',  53 , 'Action',  1 , 'Ob',  (1, 10.0, 4.81) , 'R',  0 , 'Total Reward',  32     ),                                                                                                
    ('Ticks',  54 , 'Action',  0 , 'Ob',  (0, '7.40', 5.28) , 'R',  3 , 'Total Reward',  35     ),                                                                                                            
    ('Ticks',  55 , 'Action',  0 , 'Ob',  (0, '10.3', 8.08) , 'R',  3 , 'Total Reward',  38      ),
    ('Ticks',  56 , 'Action',  0 , 'Ob',  (0, '12.4', 0.0) , 'R',  3 , 'Total Reward',  41         ),                                        
    ('Ticks',  57 , 'Action',  0 , 'Ob',  (0, '8.82', 6.71) , 'R',  3 , 'Total Reward',  44 ),                         
    ('Ticks',  58 , 'Action',  0 , 'Ob',  (0, '12.5', 0.0) , 'R',  3 , 'Total Reward',  47  ),                                
    ('Ticks',  59 , 'Action',  0 , 'Ob',  (0, '10.8', 8.52) , 'R',  3 , 'Total Reward',  50   ),                                 
    ('Ticks',  60 , 'Action',  0 , 'Ob',  (0, '8.83', 6.77) , 'R',  3 , 'Total Reward',  53     )                              
]

# %%
# x axis values 
x1 =  [float(x[1]) for x in Qlearning_experiment]
#print (x)
# corresponding y axis values 
y1 = [float(x[9]) for x in Qlearning_experiment]
#print (y)

# plotting the points  
#plt.plot(x, y) 
plt.plot(x1, y1, label = "Qlearning Experiment")  

y2 = [float(x[9]) for x in Random_experiment]
plt.plot(x1, y2, label = "Random_experiment")  

y3 = [float(x[9]) for x in DeepQN]
plt.plot(x1, y3, label = "DeepQN")  


# naming the x axis 
plt.xlabel('No. of Runs') 
# naming the y axis 
#plt.ylabel('Link Throughput') 

# giving a title to my graph 
plt.title("Total Cumulative Reward") 

# show a legend on the plot 
plt.legend(loc=9, bbox_to_anchor=(1.3, 0.3))

# function to show the plot 
plt.show()
