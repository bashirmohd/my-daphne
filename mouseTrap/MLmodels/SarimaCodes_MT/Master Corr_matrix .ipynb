# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import statsmodels.api as sm
import warnings
import itertools
from datetime import datetime
warnings.filterwarnings("ignore")
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] =12
matplotlib.rcParams['text.color'] = 'k'

# Load specific forecasting tools
from statsmodels.tsa.api import VAR, DynamicVAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse

# %%
path_to_data = 'https://media.githubusercontent.com/media/bashirmohd/OneYearSarimaData/master/fulldata_1hour.csv'

# %%
df = pd.read_csv(path_to_data)

# %%
df.head()
# Out:
#                Time  SACR_SUNN_in  SACR_SUNN_out  LOND_NEWY_in  LOND_NEWY_out  \
# 0  01/01/2018 08:00      1.411093       1.025131      0.110924       0.868312
# 1  01/01/2018 09:00      1.345362       0.919156      0.124226       0.518124
# 2  01/01/2018 10:00      1.216888       0.779384      0.200632       1.224286
# 3  01/01/2018 11:00      1.123120       0.709724      0.107318       0.471764
# 4  01/01/2018 12:00      1.078085       0.804829      0.086451       0.198725
#
#    JGI_SACR_in  JGI_SACR_out  HOUS_PANTEX_in  HOUS_PANTEX_out  BOIS_PNWG_in  \
# 0     0.008290      0.047195        0.005665         0.002810      0.001118
# 1     0.000004      0.047017        0.004931         0.002024      0.000707
# 2     0.000004      0.025432        0.005684         0.001308      0.005133
# 3     0.008277      0.016707        0.004665         0.001534      0.000522
# 4     0.000003      0.011370        0.003097         0.002302      0.000750
#
# ...

# %%
#df = df.dropna()

# %%
df.shape
# Out:
# (1048575, 102)

# %%
corr = df.corr()
#corr = df.corr().round(2)
plt.figure(figsize = (20,20))
sns.heatmap(corr,cmap='coolwarm',annot=True)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams.update({'font.size': 0})
plt.savefig('1hrfulldata_corr_plot.png')
df.to_csv('1hrfulldata_corr_data.csv')

# %%
pwd
# Out:
# '/Users/bashirm/Documents/GitHub/daphne/mouseTrap/MLmodels/SarimaCodes_MT'
